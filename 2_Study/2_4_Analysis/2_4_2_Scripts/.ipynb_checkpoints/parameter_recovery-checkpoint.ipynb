# %%
# hddm
import hddm
import kabuki
import pymc

# design matrix
from patsy import dmatrix

# data analysis
import pandas as pd
import numpy as np

# plot
import seaborn as sns
import matplotlib.pyplot as plt
import arviz as az
import ptitprince as pt

# parallel processing related
from p_tqdm import p_map
from functools import partial
from joblib import Parallel,delayed

# rmANOVA
from statsmodels.stats.anova import AnovaRM

# search file
import glob

# system
import os,sys,time
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/parallel.py:12: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   warn("The `IPython.parallel` package has been deprecated since IPython 4.0. "

# %%
# add `script` to the python path so that we can import the scripts
# scripts_dir = '/home/jovyan/work/scripts'
scripts_dir = '/home/jovyan/scripts'
sys.path.append(scripts_dir)

from HDDMarviz import HDDMarviz
from InferenceDataFromHDDM import InferenceDataFromHDDM
from plot_ppc_by_cond import plot_ppc_by_cond

# %%
print('The current HDDM version is', hddm.__version__) # 0.8.0
print('The current Kabuki version is', kabuki.__version__) # 0.6.4
print('The current PyMC version is', pymc.__version__) # 2.3.8
print('The current Numpy version is', np.__version__) 
print('The current Pandas version is', pd.__version__)
print('The current seaborn version is', sns.__version__)
# Out:
# The current HDDM version is 0.8.0
# The current Kabuki version is 0.6.4
# The current PyMC version is 2.3.8
# The current Numpy version is 1.20.3
# The current Pandas version is 1.3.5
# The current seaborn version is 0.11.2

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.8/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.8/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Experiment Design

# %% [markdown]
# It is a car-face discrimination task in a 2* 2  factorial within-subject design.
#
# Experimental factors **"stimulus coherence”(with level "low" and "high")** and **"spatial prioritization"(with level "yes" and "no")**.
#
# Experimental manipulation has four levels:
#
#
#
#
# |level|coherence|prioritization|
# | -------- | -------- | -------- |
# |1|high|yes|
# |2|high|no|
# |3|low|yes|
# |4|low|no|

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rmm71hlded.png?imageView2/0/w/960/h/960)

# %% [markdown]
# we assume that the effect of experimental design is reflected in underlying latent variable.
#
# Different levels corresponds to different parameters.
#
# For the moment, we assume **phase coherence** can influence **drift rate(v)** and **spatial priotiziation** can influence **initial bias(z)**.
#
# Because phase coherence have two levels(high & low) and spatial priotization(yes & no) have two levels, we have four levels together.

# %% [markdown]
# # Situation1

# %% [markdown]
# ## Simulate data for the experiment

# %% [markdown]
# Because we need to code the response according to the stimulus, so we must transform the varibale 'stimulus'.
#
# We assume that stimulus influence the parameter 'z'.
#
# Due to the response is pressing 'car' or 'face', instead of accuracy coding, we set the stimulus(button press) as the boundaries.
#
# So, when there are some bias, one stimulus is ``z``, another is ``1-z``.

# %%
# set the random seed
np.random.seed(123)

# set number of subjects and number of trials per level for the simulated experiment.
n_subjects = 20
trials_per_level = 72

# set up parameters of DDM for four levels of the stimulus face(1).
level1_a = {'v':.8, 'a':2, 't':.3, 'z':.8, 'sv':0, 'sz':0, 'st':0}
level2_a = {'v':.8, 'a':2, 't':.3, 'z':.5, 'sv':0, 'sz':0, 'st':0}
level3_a = {'v':.2, 'a':2, 't':.3, 'z':.8, 'sv':0, 'sz':0, 'st':0}
level4_a = {'v':.2, 'a':2, 't':.3, 'z':.5, 'sv':0, 'sz':0, 'st':0}

# set up parameters of DDM for four levels of the stimulus car(0).
level1_b = {'v':.8, 'a':2, 't':.3, 'z':.2, 'sv':0, 'sz':0, 'st':0}
level2_b = {'v':.8, 'a':2, 't':.3, 'z':.5, 'sv':0, 'sz':0, 'st':0}
level3_b = {'v':.2, 'a':2, 't':.3, 'z':.2, 'sv':0, 'sz':0, 'st':0}
level4_b = {'v':.2, 'a':2, 't':.3, 'z':.5, 'sv':0, 'sz':0, 'st':0}

# generate simulated data
np.random.seed(123)
data_a, params_a = hddm.generate.gen_rand_data({'level1':level1_a,
                                             'level2':level2_a,
                                             'level3':level3_a,
                                             'level4':level4_a},
                                             size = trials_per_level,
                                             subjs = n_subjects)
data_b, params_b = hddm.generate.gen_rand_data({'level1':level1_b,
                                             'level2':level2_b,
                                             'level3':level3_b,
                                             'level4':level4_b},
                                             size = trials_per_level,
                                             subjs = n_subjects
)
# add column stimulus
data_a['stimulus'] = pd.Series(np.ones((len(data_a))), index=data_a.index)   # face
data_b['stimulus'] = pd.Series(np.ones((len(data_b)))*0, index=data_a.index) # car

# combine the data from two stimulus
data = data_a.append(data_b,ignore_index=True)

# add column coherence
data.loc[(data['condition']=='level1')|(data['condition']=='level2'),'coherence'] = 1    
data.loc[(data['condition']=='level3')|(data['condition']=='level4'),'coherence'] = 0

# add column spatial priotiziation
data.loc[(data['condition']=='level1')|(data['condition']=='level3'),'attention'] = 1    
data.loc[(data['condition']=='level2')|(data['condition']=='level4'),'attention'] = 0

# %% [markdown]
# ## check the data

# %% [markdown]
# we can check how many trials per condition.

# %%
data.groupby(['subj_idx','stimulus','condition','coherence','attention']).size()
# Out:
# subj_idx  stimulus  condition  coherence  attention
# 0         0.0       level1     1.0        1.0          72
#                     level2     1.0        0.0          72
#                     level3     0.0        1.0          72
#                     level4     0.0        0.0          72
#           1.0       level1     1.0        1.0          72
#                                                        ..
# 19        0.0       level4     0.0        0.0          72
#           1.0       level1     1.0        1.0          72
#                     level2     1.0        0.0          72
#                     level3     0.0        1.0          72
#                     level4     0.0        0.0          72
# Length: 160, dtype: int64

# %%
data.groupby(['stimulus','coherence','attention','response'])['rt'].agg(['size','mean','std']).head(20)
# Out:
#                                        size      mean       std
# stimulus coherence attention response
# 0.0      0.0       0.0       0.0        494  1.197994  0.681693
#                              1.0        946  1.233243  0.771780
#                    1.0       0.0        974  0.793781  0.665234
#                              1.0        466  1.475633  0.773954
#          1.0       0.0       0.0        206  1.059652  0.532577
#                              1.0       1234  1.066180  0.627825
#                    1.0       0.0        667  0.689168  0.535394
#                              1.0        773  1.356814  0.651742
# 1.0      0.0       0.0       0.0        631  1.181282  0.761018
#                              1.0        809  1.206190  0.777833
#                    1.0       0.0        234  1.398436  0.807061
#                              1.0       1206  0.719062  0.569091
#          1.0       0.0       0.0        281  1.109687  0.748369
#                              1.0       1159  1.093177  0.639770
#                    1.0       0.0         67  1.303904  0.690100
#                              1.0       1373  0.662359  0.501304

# %%
data.groupby(['response'])['rt'].agg(['size','mean','std'])
# Out:
#           size      mean       std
# response
# 0.0       3554  0.988948  0.713071
# 1.0       7966  1.034168  0.699816

# %%
data.groupby(['stimulus','response'])['rt'].agg(['size','mean','std'])
# Out:
#                    size      mean       std
# stimulus response
# 0.0      0.0       2341  0.872668  0.652656
#          1.0       3419  1.233921  0.711226
# 1.0      0.0       1213  1.213361  0.769203
#          1.0       4547  0.883969  0.652052

# %%
data.groupby(['coherence','response'])['rt'].agg(['size','mean','std'])
# Out:
#                     size      mean       std
# coherence response
# 0.0       0.0       2333  1.044824  0.743842
#           1.0       3427  1.078870  0.761310
# 1.0       0.0       1221  0.882184  0.637038
#           1.0       4539  1.000417  0.647587

# %%
data.groupby(['attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                     size      mean       std
# attention response
# 0.0       0.0       1612  1.158380  0.710262
#           1.0       4148  1.139131  0.700125
# 1.0       0.0       1942  0.848308  0.684412
#           1.0       3818  0.920134  0.681485

# %% [markdown]
# we can check the effect of the coherence

# %%
data.groupby(['stimulus','coherence','response'])['rt'].agg(['size','mean','std'])
# Out:
#                              size      mean       std
# stimulus coherence response
# 0.0      0.0       0.0       1468  0.929804  0.697273
#                    1.0       1412  1.313238  0.780596
#          1.0       0.0        873  0.776591  0.557122
#                    1.0       2007  1.178119  0.652501
# 1.0      0.0       0.0        865  1.240026  0.779272
#                    1.0       2015  0.914638  0.702532
#          1.0       0.0        348  1.147079  0.740528
#                    1.0       2532  0.859562  0.607933

# %% [markdown]
# Also, we can check the effect of the attention

# %%
data.groupby(['stimulus','attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                              size      mean       std
# stimulus attention response
# 0.0      0.0       0.0        700  1.157282  0.644141
#                    1.0       2180  1.138676  0.698728
#          1.0       0.0       1641  0.751260  0.617739
#                    1.0       1239  1.401503  0.702271
# 1.0      0.0       0.0        912  1.159222  0.757455
#                    1.0       1968  1.139634  0.701846
#          1.0       0.0        301  1.377394  0.782434
#                    1.0       2579  0.688875  0.534719

# %% [markdown]
# ## anova

# %%
# ANOVA
model_aovrm3way = AnovaRM(data,
                   'rt',
                   'subj_idx',
                   within=['coherence','attention','stimulus'],
                   aggregate_func='mean')
res3way=model_aovrm3way.fit()
print(res3way)
# Out:
#                           Anova
# ==========================================================
#                              F Value Num DF  Den DF Pr > F
# ----------------------------------------------------------
# coherence                    47.3861 1.0000 19.0000 0.0000
# attention                    54.1370 1.0000 19.0000 0.0000
# stimulus                      8.4608 1.0000 19.0000 0.0090
# coherence:attention           8.8058 1.0000 19.0000 0.0079
# coherence:stimulus            6.2351 1.0000 19.0000 0.0219
# attention:stimulus           21.3151 1.0000 19.0000 0.0002
# coherence:attention:stimulus 21.5495 1.0000 19.0000 0.0002
# ==========================================================

# %%
# ANOVA
model_aovrm3way = AnovaRM(data,
                   'response',
                   'subj_idx',
                   within=['coherence','attention','stimulus'],
                   aggregate_func='mean')
res3way=model_aovrm3way.fit()
print(res3way)
# Out:
#                            Anova
# ===========================================================
#                              F Value  Num DF  Den DF Pr > F
# -----------------------------------------------------------
# coherence                    403.5718 1.0000 19.0000 0.0000
# attention                     39.0544 1.0000 19.0000 0.0000
# stimulus                      43.6144 1.0000 19.0000 0.0000
# coherence:attention           18.4459 1.0000 19.0000 0.0004
# coherence:stimulus             1.5630 1.0000 19.0000 0.2264
# attention:stimulus           599.2115 1.0000 19.0000 0.0000
# coherence:attention:stimulus  21.0467 1.0000 19.0000 0.0002
# ===========================================================

# %% [markdown]
# The parameter **v** for high coherence is 0.8;
#
# the parameter **v** for low coherence is 0.2;
#
# the parameter **z** for cue of stimulus 1 is 0.8 and of stimulus 0 is 0.2;
#
# the parameter **z** for no cue is 0.5;
#
# At the same time, we assume that the response is mapping into two stimulus, car or face.

# %% [markdown]
# ### model1
#
# v~coherence,
#
# z~prioritization
#
# when we fit the data, we will face the ideal situation.
#
# $v=\alpha_0 + \alpha_1*C(coherence)$
#
# $v_{low}=\alpha_0 = 0.2$
#
# $v_{high}=\alpha_0 + \alpha_1 = 0.8$
#
#
# $z=\beta_0 + \beta_1*C(prioritization)$ + z_link_func
#
# stim = 1
#
# $z_{no}=1 - \beta_0 = 0.5$
#
# $z_{yes}=1 - (\beta_0 + \beta_1) = 0.2$
#
# stim = 0
#
# $z_{no}=\beta_0 = 0.5$
#
# $z_{yes}=\beta_0 + \beta_1 = 0.8$

# %% [markdown]
# We expect the parameter estimated is:
#
# $\alpha_0 = 0.2, \alpha_1 = 0.6$
#
# $\beta_0 = 0.5, \beta_1 = 0.3$

# %% [markdown]
# ### model2
#
# if we set $v~C(coherence)*C(prioritization), z~C(coherence)*C(prioritization)$.
#
# $v=\alpha_0 + \alpha_1*C(coherence) + \alpha_2*C(prioritization) + \alpha_3*C(coherence)*C(priorization)$
#
# $v_{low,yes}=\alpha_0 + \alpha_2 + = 0.2$
#
# $v_{high,yes}=\alpha_0 + \alpha_1 + \alpha_2 + \alpha_3= 0.8$
#
# $v_{low,no}=\alpha_0  = 0.2$
#
# $v_{high,no}=\alpha_0 + \alpha_1 = 0.8$
#
# $v=\beta_0 + \beta_1*C(coherence) + \beta_2*C(prioritization) + \beta_3*C(coherence)*C(priorization)$ + z_link_func
#
# stim = 1
#
# $z_{no,high}=1 - \beta_0 - \beta_1= 0.5$
#
# $z_{yes,high}=1 - (\beta_0 + \beta_1 + \beta_2 +\beta_3) = 0.2$
#
# $z_{no,low}=1 - \beta_0 = 0.5$
#
# $z_{yes,low}=1 - (\beta_0 + \beta_2) = 0.2$
#
# stim = 0
#
# $z_{no,high}=\beta_0 + \beta_1 = 0.5$
#
# $z_{yes,high}=\beta_0 + \beta_1 + \beta_2 + \beta_3 = 0.8$
#
# $z_{no,low}=\beta_0 = 0.5$
#
# $z_{yes,low}=\beta_0 + \beta_2 = 0.8$

# %% [markdown]
# We expect the parameter estimated is:
#
# $\alpha_0 = 0.2, \alpha_1 = 0.6, \alpha_2 = 0, \alpha_3 = 0$
#
# $\beta_0 = 0.5, \beta_2 = 0.3, \beta_1 = 0, \beta_3 = 0$

# %% [markdown]
# this is the link func. the function is to create the node of z,
#
# for stimulus 0, the node of z is $\beta_0 + \beta_1*X$
#
# for stimulus 1, the node of z is $1 - (\beta_0 + \beta_1*X)$

# %%
def z_link_func(x, data=data):
    stim = (np.asarray(dmatrix('0 + C(s, [[0], [1]])',
                              {'s': data.stimulus.loc[x.index]},return_type='dataframe'))
    )
    # Apply z = (1 - x) to flip them along 0.5
    z_flip = np.subtract(stim, x.to_frame())
    # The above inverts those values we do not want to flip,
    # so invert them back
    z_flip[stim == 0] *= -1
    return z_flip

# %% [markdown]
# ## Fit data

# %% [markdown]
# ### model1

# %%
v_reg = {'model':'v~C(coherence)','link_func':lambda x:x}
z_reg = {'model':'z~C(attention)','link_func':z_link_func}
reg_descr = [v_reg, z_reg]
m_reg = hddm.HDDMRegressor(data, reg_descr, include='z')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_C(coherence)[T.1.0]']
# Adding these covariates:
# ['z_Intercept', 'z_C(attention)[T.1.0]']

# %% [markdown]
# because we construct a glm, so we can check the design matrix and parameters.

# %% [markdown]
# this is the parameters.

# %%
# hddm/models/hddm_regression.py/line 164
params=np.matrix(m_reg.model_descrs[1]['params'])
params
# Out:
# matrix([['z_Intercept', 'z_C(attention)[T.1.0]']], dtype='<U21')

# %% [markdown]
# this is the design matrixs.

# %%
# hddm/models/hddm_regression.py/line 154
design_matrix=dmatrix('C(attention)',
                data,
                return_type="dataframe",
                NA_action="raise")
design_matrix
# Out:
#        Intercept  C(attention)[T.1.0]
# 0            1.0                  1.0
# 1            1.0                  1.0
# 2            1.0                  1.0
# 3            1.0                  1.0
# 4            1.0                  1.0
# ...          ...                  ...
# 11515        1.0                  0.0
# 11516        1.0                  0.0
# 11517        1.0                  0.0
# 11518        1.0                  0.0
# 11519        1.0                  0.0
#
# [11520 rows x 2 columns]

# %% [markdown]
# ` hddm/models/hddm_regression.py/line 174`
#
# `design_matrix.dot(params.T)`
#
# the row and line is nx2 2x1
#
# the result is $\beta_0 + \beta_1 * C(attention)$

# %% [markdown]
# Then the linear predictor need to be transformed via link function

# %% [markdown]
# ```
# def z_link_func(x, data=data):
#     stim = (np.asarray(dmatrix('0 + C(s, [[0], [1]])',
#                               {'s': data.stimulus.loc[x.index]},return_type='dataframe'))
#     )
#     # Apply z = (1 - x) to flip them along 0.5
#     z_flip = np.subtract(stim, x.to_frame())
#     # The above inverts those values we do not want to flip,
#     # so invert them back
#     z_flip[stim == 0] *= -1
#     return z_flip
# ```

# %%
np.asarray(dmatrix('0 + C(s, [[0], [1]])',
                              {'s': data.stimulus.loc[data.index]},return_type='dataframe'))
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %% [markdown]
# for stimulus 0, the result is $\beta_0 + \beta_1*X$
#
# for stimulus 1, the result is $1 - (\beta_0 + \beta_1*X)$

# %%
v_reg = {'model':'v~C(coherence)','link_func':lambda x:x}
z_reg = {'model':'z~C(attention)','link_func':lambda x:x}
reg_descr = [v_reg, z_reg]
m_reg = hddm.HDDMRegressor(data, reg_descr, include='z')
m_reg.find_starting_values()
m_reg.sample(2000,burn=1000)
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_C(coherence)[T.1.0]']
# Adding these covariates:
# ['z_Intercept', 'z_C(attention)[T.1.0]']
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# Warning: Powell optimization failed. Falling back to simplex.
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-13:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-10:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-9:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# Warning: Powell optimization failed. Falling back to simplex.
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-18:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Warning: Powell optimization failed. Falling back to simplex.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-28:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-29:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1030, in _partial_optimize
#     minimize(opt, init_vals, method=minimizer, options=minimizer_kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/_minimize.py", line 614, in minimize
#     return _minimize_powell(fun, x0, args, callback, bounds, **options)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 3031, in _minimize_powell
#     fval, x, direc1 = _linesearch_powell(func, x, direc1,
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2762, in _linesearch_powell
#     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2364, in brent
#     res = _minimize_scalar_brent(func, brack, args, **options)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2396, in _minimize_scalar_brent
#     brent.optimize()
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2180, in optimize
#     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2154, in get_bracket_info
#     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2610, in bracket
#     fc = func(*((xc,) + args))
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 2755, in myfunc
#     return func(p + alpha*xi)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 464, in function_wrapper
#     return function(np.copy(x), *(wrapper_args + args))
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1008, in opt
#     logp_evaluate = [node.logp for node in evaluate_nodes]
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1008, in <listcomp>
#     logp_evaluate = [node.logp for node in evaluate_nodes]
#   File "/opt/conda/lib/python3.8/site-packages/pymc/PyMCObjects.py", line 903, in get_logp
#     logp = self._logp.get()
#   File "LazyFunction.pyx", line 280, in pymc.LazyFunction.LazyFunction.get (pymc/LazyFunction.c:2568)
#   File "/opt/conda/lib/python3.8/site-packages/pymc/distributions.py", line 2974, in wrapper
#     return f(value, **kwds)
#   File "/opt/conda/lib/python3.8/site-packages/hddm/models/hddm_regression.py", line 30, in wiener_multi_like
#     params[reg_outcome] = params[reg_outcome].loc[value['rt'].index].values
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 931, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1153, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1094, in _getitem_iterable
#     return self.obj._reindex_with_indexers(
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/generic.py", line 4878, in _reindex_with_indexers
#     index = ensure_index(index)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 6310, in ensure_index
#     if isinstance(index_like, Index):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-8aec3357ffe9>", line 5, in <module>
#     m_reg.find_starting_values()
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 981, in find_starting_values
#     self.approximate_map(*args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1095, in approximate_map
#     self._approximate_map_subj(fall_to_simplex=fall_to_simplex, minimizer=minimizer, use_basin=use_basin, debug=debug, minimizer_kwargs=minimizer_kwargs, basin_kwargs=basin_kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1044, in _approximate_map_subj
#     self._partial_optimize(stoch_nodes, obs_nodes, fall_to_simplex=fall_to_simplex, minimizer=minimizer, use_basin=use_basin, debug=debug, minimizer_kwargs=minimizer_kwargs, basin_kwargs=basin_kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1034, in _partial_optimize
#     minimize(opt, init_vals, method='Nelder-Mead', options=minimizer_kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/_minimize.py", line 611, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 805, in _minimize_neldermead
#     fxcc = func(xcc)
#   File "/opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py", line 464, in function_wrapper
#     return function(np.copy(x), *(wrapper_args + args))
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1008, in opt
#     logp_evaluate = [node.logp for node in evaluate_nodes]
#   File "/opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py", line 1008, in <listcomp>
#     logp_evaluate = [node.logp for node in evaluate_nodes]
#   File "/opt/conda/lib/python3.8/site-packages/pymc/PyMCObjects.py", line 903, in get_logp
#     logp = self._logp.get()
#   File "LazyFunction.pyx", line 280, in pymc.LazyFunction.LazyFunction.get (pymc/LazyFunction.c:2568)
#   File "/opt/conda/lib/python3.8/site-packages/pymc/distributions.py", line 2974, in wrapper
#     return f(value, **kwds)
#   File "/opt/conda/lib/python3.8/site-packages/hddm/models/hddm_regression.py", line 30, in wiener_multi_like
#     params[reg_outcome] = params[reg_outcome].loc[value['rt'].index].values
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 931, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1153, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1093, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1308, in _get_listlike_indexer
#     if ax._index_as_unique:
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 5348, in _index_as_unique
#     return self.is_unique
#   File "pandas/_libs/properties.pyx", line 37, in pandas._libs.properties.CachedProperty.__get__
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 2023, in is_unique
#     return self._engine.is_unique
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/conda/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/conda/lib/python3.8/inspect.py", line 1477, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/opt/conda/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/conda/lib/python3.8/inspect.py", line 745, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in _partial_optimize(self, optimize_nodes, evaluate_nodes, fall_to_simplex, minimizer, use_basin, debug, minimizer_kwargs, basin_kwargs)
#    1029             try:
# -> 1030                 minimize(opt, init_vals, method=minimizer, options=minimizer_kwargs)
#    1031             except:
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     613     elif meth == 'powell':
# --> 614         return _minimize_powell(fun, x0, args, callback, bounds, **options)
#     615     elif meth == 'cg':
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3030             fx2 = fval
# -> 3031             fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3032                                                  tol=xtol * 100,
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    2761         # non-bounded minimization
# -> 2762         alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#    2763         xi = alpha_min * xi
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in brent(func, args, brack, tol, full_output, maxiter)
#    2363                'maxiter': maxiter}
# -> 2364     res = _minimize_scalar_brent(func, brack, args, **options)
#    2365     if full_output:
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_scalar_brent(func, brack, args, xtol, maxiter, **unknown_options)
#    2395     brent.set_bracket(brack)
# -> 2396     brent.optimize()
#    2397     x, fval, nit, nfev = brent.get_result(full_output=True)
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in optimize(self)
#    2179         func = self.func
# -> 2180         xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#    2181         _mintol = self._mintol
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in get_bracket_info(self)
#    2153         if brack is None:
# -> 2154             xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#    2155         elif len(brack) == 2:
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in bracket(func, xa, xb, args, grow_limit, maxiter)
#    2609     xc = xb + _gold * (xb - xa)
# -> 2610     fc = func(*((xc,) + args))
#    2611     funcalls = 3
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in myfunc(alpha)
#    2754     def myfunc(alpha):
# -> 2755         return func(p + alpha*xi)
#    2756
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(x, *wrapper_args)
#     463         ncalls[0] += 1
# --> 464         return function(np.copy(x), *(wrapper_args + args))
#     465
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in opt(values)
#    1007                 logp_optimize = [node.logp for node in optimize_nodes]
# -> 1008                 logp_evaluate = [node.logp for node in evaluate_nodes]
#    1009                 neglogp = -np.sum(logp_optimize) - np.sum(logp_evaluate)
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in <listcomp>(.0)
#    1007                 logp_optimize = [node.logp for node in optimize_nodes]
# -> 1008                 logp_evaluate = [node.logp for node in evaluate_nodes]
#    1009                 neglogp = -np.sum(logp_optimize) - np.sum(logp_evaluate)
#
# /opt/conda/lib/python3.8/site-packages/pymc/PyMCObjects.py in get_logp(self)
#     902             print_('\t' + self.__name__ + ': logp accessed.')
# --> 903         logp = self._logp.get()
#     904
#
# LazyFunction.pyx in pymc.LazyFunction.LazyFunction.get (pymc/LazyFunction.c:2568)()
#
# /opt/conda/lib/python3.8/site-packages/pymc/distributions.py in wrapper(**kwds)
#    2973         value = kwds.pop('value')
# -> 2974         return f(value, **kwds)
#    2975
#
# /opt/conda/lib/python3.8/site-packages/hddm/models/hddm_regression.py in wiener_multi_like(value, v, sv, a, z, sz, t, st, reg_outcomes, p_outlier)
#      29         for reg_outcome in reg_outcomes:
# ---> 30             params[reg_outcome] = params[reg_outcome].loc[value['rt'].index].values
#      31         return hddm.wfpt.wiener_like_multi(value['rt'].values,
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
# -> 1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4877
# -> 4878             index = ensure_index(index)
#    4879             if indexer is not None:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    6309     """
# -> 6310     if isinstance(index_like, Index):
#    6311         if copy:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-13-8aec3357ffe9> in <module>
#       4 m_reg = hddm.HDDMRegressor(df, reg_descr, include='z')
# ----> 5 m_reg.find_starting_values()
#       6 m_reg.sample(2000,burn=1000)
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in find_starting_values(self, *args, **kwargs)
#     980         if self.is_group_model:
# --> 981             self.approximate_map(*args, **kwargs)
#     982         else:
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in approximate_map(self, individual_subjs, minimizer, use_basin, fall_to_simplex, cycles, debug, minimizer_kwargs, basin_kwargs)
#    1094                 if self.is_group_model and individual_subjs and (i == len(generations) - 1):
# -> 1095                     self._approximate_map_subj(fall_to_simplex=fall_to_simplex, minimizer=minimizer, use_basin=use_basin, debug=debug, minimizer_kwargs=minimizer_kwargs, basin_kwargs=basin_kwargs)
#    1096                     continue
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in _approximate_map_subj(self, minimizer, use_basin, fall_to_simplex, debug, minimizer_kwargs, basin_kwargs)
#    1043             obs_nodes = self.nodes_db.loc[(self.nodes_db.subj_idx == subj_idx) & (self.nodes_db.observed == True)].node
# -> 1044             self._partial_optimize(stoch_nodes, obs_nodes, fall_to_simplex=fall_to_simplex, minimizer=minimizer, use_basin=use_basin, debug=debug, minimizer_kwargs=minimizer_kwargs, basin_kwargs=basin_kwargs)
#    1045
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in _partial_optimize(self, optimize_nodes, evaluate_nodes, fall_to_simplex, minimizer, use_basin, debug, minimizer_kwargs, basin_kwargs)
#    1033                     print("Warning: Powell optimization failed. Falling back to simplex.")
# -> 1034                     minimize(opt, init_vals, method='Nelder-Mead', options=minimizer_kwargs)
#    1035                 else:
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     610     if meth == 'nelder-mead':
# --> 611         return _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     612                                     **options)
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     804                         xcc = np.clip(xcc, lower_bound, upper_bound)
# --> 805                     fxcc = func(xcc)
#     806
#
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(x, *wrapper_args)
#     463         ncalls[0] += 1
# --> 464         return function(np.copy(x), *(wrapper_args + args))
#     465
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in opt(values)
#    1007                 logp_optimize = [node.logp for node in optimize_nodes]
# -> 1008                 logp_evaluate = [node.logp for node in evaluate_nodes]
#    1009                 neglogp = -np.sum(logp_optimize) - np.sum(logp_evaluate)
#
# /opt/conda/lib/python3.8/site-packages/kabuki/hierarchical.py in <listcomp>(.0)
#    1007                 logp_optimize = [node.logp for node in optimize_nodes]
# -> 1008                 logp_evaluate = [node.logp for node in evaluate_nodes]
#    1009                 neglogp = -np.sum(logp_optimize) - np.sum(logp_evaluate)
#
# /opt/conda/lib/python3.8/site-packages/pymc/PyMCObjects.py in get_logp(self)
#     902             print_('\t' + self.__name__ + ': logp accessed.')
# --> 903         logp = self._logp.get()
#     904
#
# LazyFunction.pyx in pymc.LazyFunction.LazyFunction.get (pymc/LazyFunction.c:2568)()
#
# /opt/conda/lib/python3.8/site-packages/pymc/distributions.py in wrapper(**kwds)
#    2973         value = kwds.pop('value')
# -> 2974         return f(value, **kwds)
#    2975
#
# /opt/conda/lib/python3.8/site-packages/hddm/models/hddm_regression.py in wiener_multi_like(value, v, sv, a, z, sz, t, st, reg_outcomes, p_outlier)
#      29         for reg_outcome in reg_outcomes:
# ---> 30             params[reg_outcome] = params[reg_outcome].loc[value['rt'].index].values
#      31         return hddm.wfpt.wiener_like_multi(value['rt'].values,
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1307
# -> 1308         if ax._index_as_unique:
#    1309             indexer = ax.get_indexer_for(keyarr)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in _index_as_unique(self)
#    5347         """
# -> 5348         return self.is_unique
#    5349
#
# /opt/conda/lib/python3.8/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in is_unique(self)
#    2022         """
# -> 2023         return self._engine.is_unique
#    2024
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
m_reg.plot_posteriors()

# %% [markdown]
# ### model2

# %% [markdown]
# the glm and link function is similiar to model1.

# %%
v_reg = {'model':'v~C(coherence)*C(attention)','link_func':lambda x:x}
z_reg = {'model':'z~C(coherence)*C(attention)','link_func':z_link_func}
reg_descr = [v_reg, z_reg]
m_reg2 = hddm.HDDMRegressor(data, reg_descr, include='z')
m_reg2.find_starting_values()
m_reg2.sample(2000,burn=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-3ad54f4af654> in <module>
#       1 v_reg = {'model':'v~C(coherence)*C(attention)','link_func':lambda x:x}
# ----> 2 z_reg = {'model':'z~C(coherence)*C(attention)','link_func':z_link_func}
#       3 reg_descr = [v_reg, z_reg]
#       4 m_reg2 = hddm.HDDMRegressor(data, reg_descr, include='z')
#       5 m_reg2.find_starting_values()
#
# NameError: name 'z_link_func' is not defined

# %%
m_reg2.plot_posteriors()

# %% [markdown]
# ### model3

# %% [markdown]
# In model3, we want to test if we use incorrect coding, the results of the model.

# %%
data_tmp = data
data_tmp.loc[(data_tmp['response']==1)&(data_tmp['stimulus']==0),'_response'] = 0 
data_tmp.loc[(data_tmp['response']==1)&(data_tmp['stimulus']==1),'_response'] = 1 
data_tmp.loc[(data_tmp['response']==0)&(data_tmp['stimulus']==0),'_response'] = 1
data_tmp.loc[(data_tmp['response']==0)&(data_tmp['stimulus']==1),'_response'] = 0
data_tmp['response'] = data_tmp['_response']

# %%
data_tmp
# Out:
#            rt  response  subj_idx condition  stimulus  coherence  attention  \
# 0    0.803506       1.0      14.0    level1       1.0        1.0        1.0
# 1    0.690506       1.0      14.0    level1       1.0        1.0        1.0
# 2    0.678506       1.0      14.0    level1       1.0        1.0        1.0
# 3    0.753506       1.0      14.0    level1       1.0        1.0        1.0
# 4    0.813506       1.0      14.0    level1       1.0        1.0        1.0
# ..        ...       ...       ...       ...       ...        ...        ...
# 283  0.851019       0.0      14.0    level4       0.0        0.0        0.0
# 284  0.500019       0.0      14.0    level4       0.0        0.0        0.0
# 285  0.799019       0.0      14.0    level4       0.0        0.0        0.0
# 286  1.246019       0.0      14.0    level4       0.0        0.0        0.0
# 287  0.959019       0.0      14.0    level4       0.0        0.0        0.0
#
#      _response
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ..         ...
# 283        0.0
# 284        0.0
# 285        0.0
# 286        0.0
# 287        0.0
#
# [288 rows x 8 columns]

# %% [markdown]
# we can check how many trials per condition.

# %%
data_tmp.groupby(['subj_idx','stimulus','condition','coherence','attention']).size()

# %%
data_tmp.groupby(['stimulus','coherence','attention','response'])['rt'].agg(['size','mean','std']).head(20)

# %%
data_tmp.groupby(['response'])['rt'].agg(['size','mean','std'])

# %%
data_tmp.groupby(['stimulus','response'])['rt'].agg(['size','mean','std'])

# %% [markdown]
# we can check the effect of the coherence

# %%
data_tmp.groupby(['stimulus','coherence','response'])['rt'].agg(['size','mean','std'])

# %% [markdown]
# Also, we can check the effect of the attention

# %%
data_tmp.groupby(['stimulus','attention','response'])['rt'].agg(['size','mean','std'])

# %%
v_reg = {'model':'v~C(coherence)','link_func':lambda x:x}
z_reg = {'model':'z~C(attention)','link_func':z_link_func}
reg_descr = [v_reg, z_reg]
m_reg3 = hddm.HDDMRegressor(data_tmp, reg_descr, include='z')
m_reg3.find_starting_values()
m_reg3.sample(2000,burn=1000)

# %%
m_reg3.plot_posteriors()

# %% [markdown]
# # Simulation2

# %% [markdown]
# ## simulate the data

# %% [markdown]
# To advance the simulated data similar to our true data, we adjust the value of parameter, and construct the hierarchical structure of every subjects.

# %% [markdown]
# In this part, we assume that the prioritization affect the non-decision time

# %%
# set number of subjects and number of trials per level for the simulated experiment.
n_subjects = 15
trials_per_level = 36

# set the group parameter
# intercept and slope of v
v_int = 1
v_coh = 0.5
v_sig1 = 0.2
v_sig2 = 0.1
# intercept and slope of t
t_int = 0.3
t_pri = 0.2
t_sig1 = 0.1
t_sig2 = 0.1
# intercept of a
a_int = 1.4
a_sig = 0.1
# intercept of z
z_int = 0.5
z_sig = 0.1

# set the subject parameter
# v
v_int_subj = np.random.normal(v_int,v_sig1,[n_subjects,2])
v_coh_subj = np.random.normal(v_coh,v_sig2,[n_subjects,2])
# t
t_int_subj = np.random.normal(t_int,t_sig1,[n_subjects,2])
t_pri_subj = np.random.normal(t_pri,t_sig2,[n_subjects,2])
# a
a_int_subj = np.random.normal(a_int,a_sig,[n_subjects,2])
# z
z_int_subj = np.random.normal(z_int,z_sig,[n_subjects,2])

# dataframe
df = pd.DataFrame()
for i in range(n_subjects):
    # the different v of two experimental factor 
    v_high  = v_int_subj[i] + v_coh_subj[i]
    v_low = v_int_subj[i]
    # the different t of two experimental factor
    t_yes = t_int_subj[i] + t_pri_subj[i]
    t_no = t_int_subj[i]
    # the default parameter a
    a = a_int_subj[i]
    # the default parameter z
    z = z_int_subj[i]
    # set up parameters of DDM for four levels of the stimulus face(1).
    level1_a = {'v':v_high[0], 'a':a[0], 't':t_yes[0], 'z':z[0], 'sv':0, 'sz':0, 'st':0}
    level2_a = {'v':v_high[0], 'a':a[0], 't':t_no[0], 'z':z[0], 'sv':0, 'sz':0, 'st':0}
    level3_a = {'v':v_low[0], 'a':a[0], 't':t_yes[0], 'z':z[0], 'sv':0, 'sz':0, 'st':0}
    level4_a = {'v':v_low[0], 'a':a[0], 't':t_no[0], 'z':z[0], 'sv':0, 'sz':0, 'st':0}

    # set up parameters of DDM for four levels of the stimulus car(0).
    level1_b = {'v':v_high[1], 'a':a[1], 't':t_yes[1], 'z':z[1], 'sv':0, 'sz':0, 'st':0}
    level2_b = {'v':v_high[1], 'a':a[1], 't':t_no[1], 'z':z[1], 'sv':0, 'sz':0, 'st':0}
    level3_b = {'v':v_low[1], 'a':a[1], 't':t_yes[1], 'z':z[1], 'sv':0, 'sz':0, 'st':0}
    level4_b = {'v':v_low[1], 'a':a[1], 't':t_no[1], 'z':z[1], 'sv':0, 'sz':0, 'st':0}

    # generate simulated data
    np.random.seed(123)
    data_a, params_a = hddm.generate.gen_rand_data({'level1':level1_a,
                                                 'level2':level2_a,
                                                 'level3':level3_a,
                                                 'level4':level4_a},
                                                 size = trials_per_level
                                                  )
    data_b, params_b = hddm.generate.gen_rand_data({'level1':level1_b,
                                                 'level2':level2_b,
                                                 'level3':level3_b,
                                                 'level4':level4_b},
                                                 size = trials_per_level
                                                 )
    # add column stimulus
    data_a['stimulus'] = pd.Series(np.ones((len(data_a))), index=data_a.index)   # face
    data_b['stimulus'] = pd.Series(np.ones((len(data_b)))*0, index=data_a.index) # car

    # combine the data from two stimulus
    data = data_a.append(data_b,ignore_index=True)
    
    # add subject
    data['subj_idx'] = pd.Series(np.ones((len(data)))*i, index=data.index).astype('int64')

    # add column coherence
    data.loc[(data['condition']=='level1')|(data['condition']=='level2'),'coherence'] = 1    
    data.loc[(data['condition']=='level3')|(data['condition']=='level4'),'coherence'] = 0

    # add column spatial priotiziation
    data.loc[(data['condition']=='level1')|(data['condition']=='level3'),'attention'] = 1    
    data.loc[(data['condition']=='level2')|(data['condition']=='level4'),'attention'] = 0
    
    df = df.append(data)

# %%
# the stimulus coding
df.loc[(df['stimulus']==0)&(df['response']==0),'_response']=1
df.loc[(df['stimulus']==1)&(df['response']==1),'_response']=1
df.loc[(df['stimulus']==0)&(df['response']==1),'_response']=0
df.loc[(df['stimulus']==1)&(df['response']==0),'_response']=0

# %%
df
# Out:
#            rt  response  subj_idx condition  stimulus  coherence  attention  \
# 0    0.758277       1.0         0    level1       1.0        1.0        1.0
# 1    0.479277       0.0         0    level1       1.0        1.0        1.0
# 2    0.508277       0.0         0    level1       1.0        1.0        1.0
# 3    0.641277       1.0         0    level1       1.0        1.0        1.0
# 4    0.779277       1.0         0    level1       1.0        1.0        1.0
# ..        ...       ...       ...       ...       ...        ...        ...
# 283  0.970806       1.0        14    level4       0.0        0.0        0.0
# 284  0.976806       0.0        14    level4       0.0        0.0        0.0
# 285  0.889806       1.0        14    level4       0.0        0.0        0.0
# 286  1.597806       1.0        14    level4       0.0        0.0        0.0
# 287  1.139806       1.0        14    level4       0.0        0.0        0.0
#
#      _response
# 0          1.0
# 1          0.0
# 2          0.0
# 3          1.0
# 4          1.0
# ..         ...
# 283        0.0
# 284        1.0
# 285        0.0
# 286        0.0
# 287        0.0
#
# [4320 rows x 8 columns]

# %% [markdown]
# ## check the data

# %%
df.groupby(['response'])['rt'].agg(['size','mean','std'])
# Out:
#           size      mean       std
# response
# 0.0        761  0.751876  0.374696
# 1.0       3559  0.758774  0.367719

# %%
df.groupby(['_response'])['rt'].agg(['size','mean','std'])
# Out:
#            size      mean       std
# _response
# 0.0        2139  0.764593  0.387150
# 1.0        2181  0.750660  0.350078

# %%
df.groupby(['stimulus','response'])['rt'].agg(['size','mean','std'])
# Out:
#                    size      mean       std
# stimulus response
# 0.0      0.0        391  0.804967  0.379208
#          1.0       1769  0.778987  0.390775
# 1.0      0.0        370  0.695771  0.361993
#          1.0       1790  0.738798  0.342354

# %%
df.groupby(['coherence','response'])['rt'].agg(['size','mean','std'])
# Out:
#                     size      mean       std
# coherence response
# 0.0       0.0        509  0.816895  0.414908
#           1.0       1651  0.807897  0.437350
# 1.0       0.0        252  0.620547  0.225398
#           1.0       1908  0.716268  0.287903

# %%
df.groupby(['attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                     size      mean       std
# attention response
# 0.0       0.0        405  0.701728  0.397755
#           1.0       1755  0.669380  0.362482
# 1.0       0.0        356  0.808925  0.338214
#           1.0       1804  0.845740  0.351661

# %%
df.groupby(['stimulus','coherence','response'])['rt'].agg(['size','mean','std'])
# Out:
#                              size      mean       std
# stimulus coherence response
# 0.0      0.0       0.0        256  0.878359  0.415662
#                    1.0        824  0.830703  0.468555
#          1.0       0.0        135  0.665794  0.244799
#                    1.0        945  0.733893  0.300375
# 1.0      0.0       0.0        253  0.754701  0.405558
#                    1.0        827  0.785173  0.402870
#          1.0       0.0        117  0.568339  0.188607
#                    1.0        963  0.698972  0.274170

# %%
df.groupby(['stimulus','attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                              size      mean       std
# stimulus attention response
# 0.0      0.0       0.0        229  0.773983  0.372756
#                    1.0        851  0.668553  0.367089
#          1.0       0.0        162  0.848766  0.385054
#                    1.0        918  0.881362  0.384319
# 1.0      0.0       0.0        176  0.607716  0.410472
#                    1.0        904  0.670159  0.358293
#          1.0       0.0        194  0.775655  0.290303
#                    1.0        886  0.808832  0.310195

# %%
df.groupby(['stimulus','coherence','attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                                        size      mean       std
# stimulus coherence attention response
# 0.0      0.0       0.0       0.0        145  0.832336  0.408110
#                              1.0        395  0.702933  0.420979
#                    1.0       0.0        111  0.938480  0.419583
#                              1.0        429  0.948347  0.479664
#          1.0       0.0       0.0         84  0.673254  0.276600
#                              1.0        456  0.638772  0.310420
#                    1.0       0.0         51  0.653507  0.182629
#                              1.0        489  0.822595  0.261439
# 1.0      0.0       0.0       0.0        119  0.674760  0.474993
#                              1.0        421  0.718996  0.424835
#                    1.0       0.0        134  0.825693  0.317291
#                              1.0        406  0.853796  0.366848
#          1.0       0.0       0.0         57  0.467745  0.147039
#                              1.0        483  0.627591  0.281662
#                    1.0       0.0         60  0.663904  0.174225
#                              1.0        480  0.770799  0.246634

# %% [markdown]
# ## visualize the data

# %% [markdown]
# ### the barplot

# %%
# get the mean of accurate RTs
data_rt_sum = df[df['response']==1].groupby(['subj_idx','coherence','attention','stimulus'])['rt'].mean().reset_index()
# change the type of columns
data_rt_sum['stimulus'] = data_rt_sum['stimulus'].astype('int64')
data_rt_sum['coherence'] = data_rt_sum['coherence'].astype('int64')
data_rt_sum['attention'] = data_rt_sum['attention'].astype('int64')

# set the figure theme
sns.set_theme(style="whitegrid")
# set the canvas 
g = sns.FacetGrid(data = data_rt_sum,
                  col = 'stimulus',
                  height = 5,
                  aspect = 0.8,
                  sharex = True,
                  sharey = True)
# map the dataframe to the canvas
g.map_dataframe(sns.barplot,
                x = 'coherence',
                y = 'rt',
                hue = 'attention',
                palette = 'dark',
                alpha = 0.6)
# add labels to the figure
g.set_xlabels("Coherence")
g.set_ylabels("Response Time (ms)")
g.set_titles("Stimulus: {col_name}")
g.fig.suptitle("Response Time by Coherence and Attention", 
               y=1.05, 
               fontsize=16)
g.add_legend()

# %% [markdown]
# ### the raincloud plot

# %%
f, ax = plt.subplots(1,2,figsize=(16, 8))
# the left figure
ax[0] = pt.RainCloud(x = 'coherence', 
                  y = 'rt', 
                  hue = 'attention', 
                  data = data_rt_sum[data_rt_sum['stimulus']==0], 
                  palette = 'Set2', 
                  bw = 0.6, 
                  width_viol=.5,
                  ax = ax[0], 
                  orient = 'v', 
                  alpha = .6, 
                  dodge = True, 
                  pointplot = True, 
                  move = 0.2)
ax[0].legend('')
ax[0].set_title('stimulus:0')
ax[0].set_ylabel('Response Time (ms)')
# the right figure
ax[1] = pt.RainCloud(x = 'coherence', 
                  y = 'rt', 
                  hue = 'attention', 
                  data = data_rt_sum[data_rt_sum['stimulus']==1], 
                  palette = 'Set2', 
                  bw = 0.6, 
                  width_viol=.5,
                  ax = ax[1], 
                  orient = 'v', 
                  alpha = .6, 
                  dodge = True, 
                  pointplot = True, 
                  move = 0.2)
ax[1].set_title('stimulus:1')
ax[1].set_ylabel('Response Time (ms)')
plt.suptitle("Response Time by Coherence and Attention", 
               y=1, 
               fontsize=16)
# Out:
# Text(0.5, 1, 'Response Time by Coherence and Attention')

# %% [markdown]
# ## ANOVA

# %%
# ANOVA for rt
model_aovrm3way = AnovaRM(df,
                   'rt',
                   'subj_idx',
                   within=['coherence','attention','stimulus'],
                   aggregate_func='mean')
res3way=model_aovrm3way.fit()
print(res3way)
# ANOVA for response
model_aovrm3way = AnovaRM(df,
                   'response',
                   'subj_idx',
                   within=['coherence','attention','stimulus'],
                   aggregate_func='mean')
res3way=model_aovrm3way.fit()
print(res3way)
# Out:
#                            Anova
# ===========================================================
#                              F Value  Num DF  Den DF Pr > F
# -----------------------------------------------------------
# coherence                    692.7902 1.0000 14.0000 0.0000
# attention                     91.1307 1.0000 14.0000 0.0000
# stimulus                       1.3943 1.0000 14.0000 0.2573
# coherence:attention           90.5531 1.0000 14.0000 0.0000
# coherence:stimulus            15.9311 1.0000 14.0000 0.0013
# attention:stimulus             1.3156 1.0000 14.0000 0.2706
# coherence:attention:stimulus 176.1511 1.0000 14.0000 0.0000
# ===========================================================
#
#                            Anova
# ===========================================================
#                              F Value  Num DF  Den DF Pr > F
# -----------------------------------------------------------
# coherence                    335.5174 1.0000 14.0000 0.0000
# attention                     57.5582 1.0000 14.0000 0.0000
# stimulus                       0.0692 1.0000 14.0000 0.7964
# coherence:attention            0.9496 1.0000 14.0000 0.3464
# coherence:stimulus             0.9211 1.0000 14.0000 0.3535
# attention:stimulus            97.2596 1.0000 14.0000 0.0000
# coherence:attention:stimulus   1.4641 1.0000 14.0000 0.2463
# ===========================================================

# %% [markdown]
# ## fit data

# %% [markdown]
# ### define the model

# %%
 def ms1(id, df=None, samples=None, burn=None, thin=1,save_name='ms1'):
    '''
    id: the id of cpu thread
    df: the input data
    samples: number of samples for MCMC
    burn: number of burn-in of MCMC
    thin: number of thin
    save_name: prefix of file name when saving the model object
    '''
    print('running chain {:d} for model {}'.format(id, save_name))
    # the database file
    dbname = save_name + '_chain_%i.db'%id
    # the model object store here
    mname = save_name + '_chain_%i'%id
    # define the model
    v_reg = {'model':'v~C(coherence)','link_func':lambda x:x}
    t_reg = {'model':'t~C(attention)','link_func':lambda x:x}
    reg_descr = [v_reg, t_reg]
    m = hddm.HDDMRegressor(df, 
                           reg_descr, 
                           include='z',
                           group_only_regressors=False,
                           keep_regressor_trace=True
                          )
    # find the starting point
    m.find_starting_values()
    # MCMC sample
    m.sample(samples, 
             burn=burn, 
             thin=thin, 
             dbname=dbname,
             db='pickle')
    # save
    m.save(mname)

    return m

# %% [markdown]
# ### judge whether need to sample

# %%
# %%time
# number of chains
chains=4
# file name
file_names = glob.glob('ms1'+'_chain_*[!db]',recursive=False)
# if there exists file, pass
if file_names:
    # sort filename by id
    file_names = sorted(file_names, key = lambda x:x[-1])
    ms1res = []
    for fname in file_names:
        print('current loading:',fname,'\n')
        ms1res.append(hddm.load(fname))
# else sample
else:
    ms1res = Parallel(n_jobs = 4)(delayed(ms1)(id = i, df = df, samples=2000,burn = 1000,thin=1, save_name = 'ms1' ) for i in range(4))
# Out:
# current loading: ms1_chain_0
#
# WARNING: Custom link functions will not be loaded.
# current loading: ms1_chain_1
#
# WARNING: Custom link functions will not be loaded.
# current loading: ms1_chain_2
#
# WARNING: Custom link functions will not be loaded.
# current loading: ms1_chain_3
#
# WARNING: Custom link functions will not be loaded.
# CPU times: user 41.2 s, sys: 8.27 s, total: 49.5 s
# Wall time: 49.7 s

# %%
ms1res = Parallel(n_jobs = 4)(delayed(ms1)(id = i, df = df, samples=2000,burn = 1000,thin=1, save_name = 'ms1' ) for i in range(4))
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %% [markdown]
# ### convert hddm model object to Inferencedata

# %%
# %%time
InfData_ms1 = InferenceDataFromHDDM(ms1res, nppc = 300, save_name="infdata_ms1")
# Out:
# start converting infdata_ms1
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.

# %%
# %%time
file_names = glob.glob('infdata_ms1_netcdf',recursive=False)
if file_names:
    infdata_ms1 = az.from_netcdf('infdata_ms1_netcdf')
else:
    InfData_ms1 = InferenceDataFromHDDM(ms1res, nppc = 300, save_name="infdata_ms1")

# %% [markdown]
# ## visualization

# %% [markdown]
# ### plot traces

# %%
m1 = kabuki.utils.concat_models(ms1res)
m1.plot_posteriors()

# %%
az.plot_trace(InfData_ms1, var_names=("^v(?!.*(subj|std))"), filter_vars='regex')

# %%
az.plot_trace(InfData_ms1, var_names=("^t(?!.*(subj|std))"), filter_vars='regex')

# %% [markdown]
# ### summary data

# %%
ms1_summary_tmp = az.summary(InfData_ms1, round_to=4)
ms1_summary_tmp.sort_values('r_hat')

# %% [markdown]
# ### posterior predictive check

# %%
az.plot_ppc(InfData_ms1,
            var_names=['rt','response'], 
            textsize=20, 
            num_pp_samples=300, 
            alpha = 0.2)

# %% [markdown]
# ### Check dic, loo and waic

# %%
# dic
m1.dic
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.

# %%
# loo
az.loo(InfData_ms1, scale="deviance")

# %%
# waic
az.waic(InfData_ms1, scale="deviance")

# %% [markdown]
# ### posterior predictive check by condition

# %%
# coherence
plot_ppc_by_cond(data = InfData_ms1, 
                 or_d = df, 
                 subjs = [3], 
                 conds = ['coherence'], 
                 num_pp_samples=300, 
                 random_seed = 7, 
                 alpha = 0.2, 
                 grid = [2,2], 
                 textsize=20, 
                 var_names=['rt'])

# %%
# attention
plot_ppc_by_cond(data = InfData_ms1, 
                 or_d = df, 
                 subjs = [3], 
                 conds = ['attention'], 
                 num_pp_samples=300, 
                 random_seed = 7, 
                 alpha = 0.2, 
                 grid = [2,2], 
                 textsize=20, 
                 var_names=['rt'])

# %% [markdown]
# ## Statistical Inference

# %%
# v_int
az.plot_posterior(InfData['ms1'], 
                  filter_vars='regex', 
                  var_names=("^v_(?!.*(subj|std|Intercept))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=v_int)

# %%
# v_coh
az.plot_posterior(InfData['ms1'], 
                  filter_vars='regex', 
                  var_names=("^v_(?!.*(subj|std|coherence))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=v_coh)

# %%
# t_int
az.plot_posterior(InfData['ms1'], 
                  filter_vars='regex', 
                  var_names=("^t_(?!.*(subj|std|Intercept))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=t_int)

# %%
# t_coh
az.plot_posterior(InfData['ms1'], 
                  filter_vars='regex', 
                  var_names=("^t_(?!.*(subj|std|attention))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=t_pri)

# %% [markdown]
# # Simulation3

# %% [markdown]
# ## simulate the data

# %%
# set number of subjects and number of trials per level for the simulated experiment.
n_subjects = 15
trials_per_level = 36

# set the group parameter
# intercept and slope of v
v_int = 1
v_coh = 0.5
v_sig1 = 0.2
v_sig2 = 0.1
# intercept and slope of z
z_int = 0.5
z_pri = 0.2
z_sig1 = 0.1
z_sig2 = 0.05
# intercept of a
a_int = 1.4
a_sig = 0.1
# intercept of t
t_int = 0.4
t_sig = 0.1

# set the subject parameter
# v
v_int_subj = np.random.normal(v_int,v_sig1,[n_subjects,2])
v_coh_subj = np.random.normal(v_coh,v_sig2,[n_subjects,2])
# z
z_int_subj = np.random.normal(z_int,z_sig1,[n_subjects,2])
z_pri_subj = np.random.normal(z_pri,z_sig2,[n_subjects,2])
# a
a_int_subj = np.random.normal(a_int,a_sig,[n_subjects,2])
# t
t_int_subj = np.random.normal(t_int,t_sig,[n_subjects,2])

# dataframe
df = pd.DataFrame()
for i in range(n_subjects):
    
    # the different v of two experimental factor 
    v_high  = v_int_subj[i] + v_coh_subj[i]
    v_low = v_int_subj[i]
    # the different t of two experimental factor
    z_yes = z_int_subj[i] + z_pri_subj[i]
    z_no = z_int_subj[i]
    # the default parameter a
    a = a_int_subj[i]
    # the default parameter t
    t = t_int_subj[i]
    
    # set up parameters of DDM for four levels of the stimulus face(1).
    level1_a = {'v':v_high[0], 'a':a[0], 't':t[0], 'z':z_yes[0], 'sv':0, 'sz':0, 'st':0}
    level2_a = {'v':v_high[0], 'a':a[0], 't':t[0], 'z':z_no[0], 'sv':0, 'sz':0, 'st':0}
    level3_a = {'v':v_low[0], 'a':a[0], 't':t[0], 'z':z_yes[0], 'sv':0, 'sz':0, 'st':0}
    level4_a = {'v':v_low[0], 'a':a[0], 't':t[0], 'z':z_no[0], 'sv':0, 'sz':0, 'st':0}

    # set up parameters of DDM for four levels of the stimulus car(0).
    level1_b = {'v':v_high[1], 'a':a[1], 't':t[1], 'z':z_yes[0], 'sv':0, 'sz':0, 'st':0}
    level2_b = {'v':v_high[1], 'a':a[1], 't':t[1], 'z':z_no[0], 'sv':0, 'sz':0, 'st':0}
    level3_b = {'v':v_low[1], 'a':a[1], 't':t[1], 'z':z_yes[0], 'sv':0, 'sz':0, 'st':0}
    level4_b = {'v':v_low[1], 'a':a[1], 't':t[1], 'z':z_no[0], 'sv':0, 'sz':0, 'st':0}

    # generate simulated data
    np.random.seed(123)
    data_a, params_a = hddm.generate.gen_rand_data({'level1':level1_a,
                                                 'level2':level2_a,
                                                 'level3':level3_a,
                                                 'level4':level4_a},
                                                 size = trials_per_level
                                                  )
    data_b, params_b = hddm.generate.gen_rand_data({'level1':level1_b,
                                                 'level2':level2_b,
                                                 'level3':level3_b,
                                                 'level4':level4_b},
                                                 size = trials_per_level
                                                 )
    # add column stimulus
    data_a['stimulus'] = pd.Series(np.ones((len(data_a))), index=data_a.index)   # face
    data_b['stimulus'] = pd.Series(np.ones((len(data_b)))*0, index=data_a.index) # car

    # combine the data from two stimulus
    data = data_a.append(data_b,ignore_index=True)
    
    # add subject
    data['subj_idx'] = pd.Series(np.ones((len(data)))*i, index=data.index).astype('int64')

    # add column coherence
    data.loc[(data['condition']=='level1')|(data['condition']=='level2'),'coherence'] = 1    
    data.loc[(data['condition']=='level3')|(data['condition']=='level4'),'coherence'] = 0

    # add column spatial priotiziation
    data.loc[(data['condition']=='level1')|(data['condition']=='level3'),'attention'] = 1    
    data.loc[(data['condition']=='level2')|(data['condition']=='level4'),'attention'] = 0
    
    df = df.append(data)

# %%
# the stimulus coding
df.loc[(df['stimulus']==0)&(df['response']==0),'_response']=1
df.loc[(df['stimulus']==1)&(df['response']==1),'_response']=1
df.loc[(df['stimulus']==0)&(df['response']==1),'_response']=0
df.loc[(df['stimulus']==1)&(df['response']==0),'_response']=0

# %% [markdown]
# ## check the data

# %%
df
# Out:
#            rt  response  subj_idx condition  stimulus  coherence  attention  \
# 0    0.451742       1.0         0    level1       1.0        1.0        1.0
# 1    0.359742       1.0         0    level1       1.0        1.0        1.0
# 2    0.353742       1.0         0    level1       1.0        1.0        1.0
# 3    0.403742       1.0         0    level1       1.0        1.0        1.0
# 4    0.462742       1.0         0    level1       1.0        1.0        1.0
# ..        ...       ...       ...       ...       ...        ...        ...
# 283  0.733101       1.0        14    level4       0.0        0.0        0.0
# 284  0.823101       0.0        14    level4       0.0        0.0        0.0
# 285  0.645101       1.0        14    level4       0.0        0.0        0.0
# 286  1.433101       1.0        14    level4       0.0        0.0        0.0
# 287  0.921101       1.0        14    level4       0.0        0.0        0.0
#
#      _response
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ..         ...
# 283        0.0
# 284        1.0
# 285        0.0
# 286        0.0
# 287        0.0
#
# [4320 rows x 8 columns]

# %%
df.groupby(['response'])['rt'].agg(['size','mean','std'])
# Out:
#           size      mean       std
# response
# 0.0        495  0.830843  0.371376
# 1.0       3825  0.694650  0.314067

# %%
df.groupby(['_response'])['rt'].agg(['size','mean','std'])
# Out:
#            size      mean      std
# _response
# 0.0        1969  0.721549  0.33488
# 1.0        2351  0.700797  0.31440

# %%
df.groupby(['stimulus','response'])['rt'].agg(['size','mean','std'])
# Out:
#                    size      mean       std
# stimulus response
# 0.0      0.0        343  0.859261  0.351141
#          1.0       1817  0.717771  0.327941
# 1.0      0.0        152  0.766715  0.407398
#          1.0       2008  0.673729  0.299509

# %%
df.groupby(['coherence','response'])['rt'].agg(['size','mean','std'])
# Out:
#                     size      mean       std
# coherence response
# 0.0       0.0        343  0.888127  0.401633
#           1.0       1817  0.733874  0.375283
# 1.0       0.0        152  0.701576  0.248167
#           1.0       2008  0.659158  0.240522

# %%
df.groupby(['attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                     size      mean       std
# attention response
# 0.0       0.0        373  0.824477  0.383084
#           1.0       1787  0.769621  0.335595
# 1.0       0.0        122  0.850306  0.333762
#           1.0       2038  0.628913  0.277794

# %%
df.groupby(['stimulus','coherence','response'])['rt'].agg(['size','mean','std'])
# Out:
#                              size      mean       std
# stimulus coherence response
# 0.0      0.0       0.0        233  0.901571  0.381863
#                    1.0        847  0.764484  0.397922
#          1.0       0.0        110  0.769638  0.254101
#                    1.0        970  0.676981  0.244407
# 1.0      0.0       0.0        110  0.859649  0.441081
#                    1.0        970  0.707145  0.352371
#          1.0       0.0         42  0.523318  0.100918
#                    1.0       1038  0.642502  0.235736

# %%
df.groupby(['stimulus','attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                              size      mean       std
# stimulus attention response
# 0.0      0.0       0.0        258  0.863892  0.347253
#                    1.0        822  0.775672  0.344820
#          1.0       0.0         85  0.845201  0.364431
#                    1.0        995  0.669937  0.305306
# 1.0      0.0       0.0        115  0.736048  0.442302
#                    1.0        965  0.764466  0.327624
#          1.0       0.0         37  0.862032  0.253627
#                    1.0       1043  0.589778  0.242488

# %%
df.groupby(['stimulus','coherence','attention','response'])['rt'].agg(['size','mean','std'])
# Out:
#                                        size      mean       std
# stimulus coherence attention response
# 0.0      0.0       0.0       0.0        167  0.897722  0.382109
#                              1.0        373  0.812028  0.399998
#                    1.0       0.0         66  0.911311  0.383988
#                              1.0        474  0.727071  0.392669
#          1.0       0.0       0.0         91  0.801809  0.262701
#                              1.0        449  0.745471  0.288143
#                    1.0       0.0         19  0.615558  0.125066
#                              1.0        521  0.617957  0.179561
# 1.0      0.0       0.0       0.0         77  0.841955  0.503747
#                              1.0        463  0.803339  0.388021
#                    1.0       0.0         33  0.900935  0.239796
#                              1.0        507  0.619299  0.290022
#          1.0       0.0       0.0         38  0.521447  0.104292
#                              1.0        502  0.728613  0.254968
#                    1.0       0.0          4  0.541088  0.067640
#                              1.0        536  0.561853  0.182656

# %% [markdown]
# ## visualize the data

# %% [markdown]
# ### the barplot

# %%
# get the mean of accurate RTs
data_rt_sum = df[df['response']==1].groupby(['subj_idx','coherence','attention','stimulus'])['rt'].mean().reset_index()
# change the type of columns
data_rt_sum['stimulus'] = data_rt_sum['stimulus'].astype('int64')
data_rt_sum['coherence'] = data_rt_sum['coherence'].astype('int64')
data_rt_sum['attention'] = data_rt_sum['attention'].astype('int64')

# set the figure theme
sns.set_theme(style="whitegrid")
# set the canvas 
g = sns.FacetGrid(data = data_rt_sum,
                  col = 'stimulus',
                  height = 5,
                  aspect = 0.8,
                  sharex = True,
                  sharey = True)
# map the dataframe to the canvas
g.map_dataframe(sns.barplot,
                x = 'coherence',
                y = 'rt',
                hue = 'attention',
                palette = 'dark',
                alpha = 0.6)
# add labels to the figure
g.set_xlabels("Coherence")
g.set_ylabels("Response Time (ms)")
g.set_titles("Stimulus: {col_name}")
g.fig.suptitle("Response Time by Coherence and Attention", 
               y=1.05, 
               fontsize=16)
g.add_legend()

# %% [markdown]
# ### the raincloud plot

# %%
f, ax = plt.subplots(1,2,figsize=(16, 8))
# the left figure
ax[0] = pt.RainCloud(x = 'coherence', 
                  y = 'rt', 
                  hue = 'attention', 
                  data = data_rt_sum[data_rt_sum['stimulus']==0], 
                  palette = 'Set2', 
                  bw = 0.6, 
                  width_viol=.5,
                  ax = ax[0], 
                  orient = 'v', 
                  alpha = .6, 
                  dodge = True, 
                  pointplot = True, 
                  move = 0.2)
ax[0].legend('')
ax[0].set_title('stimulus:0')
ax[0].set_ylabel('Response Time (ms)')
# the right figure
ax[1] = pt.RainCloud(x = 'coherence', 
                  y = 'rt', 
                  hue = 'attention', 
                  data = data_rt_sum[data_rt_sum['stimulus']==1], 
                  palette = 'Set2', 
                  bw = 0.6, 
                  width_viol=.5,
                  ax = ax[1], 
                  orient = 'v', 
                  alpha = .6, 
                  dodge = True, 
                  pointplot = True, 
                  move = 0.2)
ax[1].set_title('stimulus:1')
ax[1].set_ylabel('Response Time (ms)')
plt.suptitle("Response Time by Coherence and Attention", 
               y=1, 
               fontsize=16)
# Out:
# Text(0.5, 1, 'Response Time by Coherence and Attention')

# %% [markdown]
# ## ANOVA

# %%
# ANOVA for rt
model_aovrm3way = AnovaRM(df,
                   'rt',
                   'subj_idx',
                   within=['coherence','attention','stimulus'],
                   aggregate_func='mean')
res3way=model_aovrm3way.fit()
print(res3way)
# ANOVA for response
model_aovrm3way = AnovaRM(df,
                   'response',
                   'subj_idx',
                   within=['coherence','attention','stimulus'],
                   aggregate_func='mean')
res3way=model_aovrm3way.fit()
print(res3way)
# Out:
#                            Anova
# ============================================================
#                               F Value  Num DF  Den DF Pr > F
# ------------------------------------------------------------
# coherence                    1023.0452 1.0000 14.0000 0.0000
# attention                     240.4122 1.0000 14.0000 0.0000
# stimulus                        2.8886 1.0000 14.0000 0.1113
# coherence:attention            10.8209 1.0000 14.0000 0.0054
# coherence:stimulus              8.7512 1.0000 14.0000 0.0104
# attention:stimulus             35.7340 1.0000 14.0000 0.0000
# coherence:attention:stimulus  235.7118 1.0000 14.0000 0.0000
# ============================================================
#
#                            Anova
# ===========================================================
#                              F Value  Num DF  Den DF Pr > F
# -----------------------------------------------------------
# coherence                    161.4204 1.0000 14.0000 0.0000
# attention                    100.1833 1.0000 14.0000 0.0000
# stimulus                      31.5580 1.0000 14.0000 0.0001
# coherence:attention            7.3326 1.0000 14.0000 0.0170
# coherence:stimulus            34.7131 1.0000 14.0000 0.0000
# attention:stimulus           103.5656 1.0000 14.0000 0.0000
# coherence:attention:stimulus   3.2733 1.0000 14.0000 0.0919
# ===========================================================

# %% [markdown]
# ## fit data

# %% [markdown]
# ### define the model

# %%
 def ms2(id, df=None, samples=None, burn=None, thin=1,save_name='ms1'):
        '''
        id: the id of cpu thread
        df: the input data
        samples: number of samples for MCMC
        burn: number of burn-in of MCMC
        thin: number of thin
        save_name: prefix of file name when saving the model object
        '''
        print('running chain {:d} for model {}'.format(id, save_name))
        # the database file
        dbname = save_name + '_chain_%i.db'%id
        # the model object store here
        mname = save_name + '_chain_%i'%id
        # define the model
        v_reg = {'model':'v~C(coherence)','link_func':lambda x:x}
        z_reg = {'model':'z~C(attention)','link_func':lambda x:x}
        reg_descr = [v_reg, z_reg]
        m = hddm.HDDMRegressor(df, 
                               reg_descr, 
                               include=['z'],
                               group_only_regressors=False,
                               keep_regressor_trace=True
                               )
        # find the starting point
        m.find_starting_values()
        # MCMC sample
        m.sample(samples, 
                 burn=burn, 
                 thin=thin, 
                 dbname=dbname,
                 db='pickle')
        # save
        m.save(mname)
        
        return m

# %% [markdown]
# ### judge whether need to sample

# %%
# %%time
# number of chains
chains=4
# file name
file_names = glob.glob('ms2'+'_chain_*[!db]',recursive=False)
# if there exists file, pass
if file_names:
    # sort filename by id
    file_names = sorted(file_names, key = lambda x:x[-1])
    ms2res = []
    for fname in file_names:
        print('current loading:',fname,'\n')
        ms2res.append(hddm.load(fname))
# else sample
else:
    ms2res = Parallel(n_jobs = 4)(delayed(ms2)(id = i, df = df, samples=4000,burn = 2000,thin=2, save_name = 'ms2' ) for i in range(4))
# Out:
# current loading: ms2_chain_0
#
# WARNING: Custom link functions will not be loaded.
# current loading: ms2_chain_1
#
# WARNING: Custom link functions will not be loaded.
# CPU times: user 17.9 s, sys: 2.91 s, total: 20.8 s
# Wall time: 20.8 s

# %%
ms2res = Parallel(n_jobs = 4)(delayed(ms2)(id = i, df = df, samples=2000,burn = 1000,thin=1, save_name = 'ms2' ) for i in range(4))
# Out:
# running chain 0 for model ms2
# running chain 1 for model ms2
# Adding these covariates:
# ['v_Intercept', 'v_C(coherence)[T.1.0]']
# Adding these covariates:
# ['v_Intercept', 'v_C(coherence)[T.1.0]']
# Adding these covariates:
# ['z_Intercept', 'z_C(attention)[T.1.0]']
# Adding these covariates:
# ['z_Intercept', 'z_C(attention)[T.1.0]']
# running chain 3 for model ms2
# running chain 2 for model ms2
# Adding these covariates:
# ['v_Intercept', 'v_C(coherence)[T.1.0]']
# Adding these covariates:
# ['z_Intercept', 'z_C(attention)[T.1.0]']
# Adding these covariates:
# ['v_Intercept', 'v_C(coherence)[T.1.0]']
# Adding these covariates:
# ['z_Intercept', 'z_C(attention)[T.1.0]']
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/yikang1020/anaconda3/envs/hddm38/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# [                  0%                  ] 2 of 2000 complete in 1.3 sec
# [                  0%                  ] 2 of 2000 complete in 1.3 sec
# [                  0%                  ] 2 of 2000 complete in 1.3 sec
# [                  0%                  ] 2 of 2000 complete in 1.4 sec
# [                  0%                  ] 3 of 2000 complete in 2.7 sec
# [                  0%                  ] 3 of 2000 complete in 2.7 sec
# [                  0%                  ] 3 of 2000 complete in 2.8 sec
# [                  0%                  ] 3 of 2000 complete in 3.1 sec
# [                  0%                  ] 4 of 2000 complete in 4.1 sec
# [                  0%                  ] 4 of 2000 complete in 4.2 sec
# [                  0%                  ] 4 of 2000 complete in 4.4 sec
# [                  0%                  ] 4 of 2000 complete in 4.7 sec
# [                  0%                  ] 5 of 2000 complete in 5.6 sec
# [                  0%                  ] 5 of 2000 complete in 5.7 sec
# [                  0%                  ] 5 of 2000 complete in 5.9 sec
# [                  0%                  ] 5 of 2000 complete in 6.3 sec
# [                  0%                  ] 6 of 2000 complete in 7.3 sec
# [                  0%                  ] 6 of 2000 complete in 7.2 sec
# [                  0%                  ] 6 of 2000 complete in 7.5 sec
# [                  0%                  ] 6 of 2000 complete in 8.0 sec
# [                  0%                  ] 7 of 2000 complete in 8.9 sec
# [                  0%                  ] 7 of 2000 complete in 8.7 sec
# [                  0%                  ] 7 of 2000 complete in 9.0 sec
# [                  0%                  ] 7 of 2000 complete in 9.5 sec
# [                  0%                  ] 8 of 2000 complete in 10.4 sec
# [                  0%                  ] 8 of 2000 complete in 10.2 sec
# [                  0%                  ] 8 of 2000 complete in 10.6 sec
# [                  0%                  ] 8 of 2000 complete in 11.1 sec
# [                  0%                  ] 9 of 2000 complete in 12.0 sec
# [                  0%                  ] 9 of 2000 complete in 11.7 sec
# [                  0%                  ] 9 of 2000 complete in 12.2 sec
# [                  0%                  ] 9 of 2000 complete in 12.8 sec
# [                  0%                  ] 10 of 2000 complete in 13.0 sec
# [                  0%                  ] 10 of 2000 complete in 13.6 sec
# [                  0%                  ] 10 of 2000 complete in 13.9 sec
# [                  0%                  ] 11 of 2000 complete in 14.5 sec
# [                  0%                  ] 11 of 2000 complete in 15.1 sec
# [                  0%                  ] 10 of 2000 complete in 14.5 sec
# [                  0%                  ] 11 of 2000 complete in 15.4 sec
# [                  0%                  ] 12 of 2000 complete in 16.0 sec
# [                  0%                  ] 12 of 2000 complete in 16.7 sec
# [                  0%                  ] 11 of 2000 complete in 16.1 sec
# [                  0%                  ] 12 of 2000 complete in 17.0 sec
# [                  0%                  ] 13 of 2000 complete in 17.5 sec
# [                  0%                  ] 13 of 2000 complete in 18.3 sec
# [                  0%                  ] 12 of 2000 complete in 17.7 sec
# [                  0%                  ] 13 of 2000 complete in 18.6 sec
# [                  0%                  ] 14 of 2000 complete in 19.1 sec
# [                  0%                  ] 14 of 2000 complete in 19.7 sec
# [                  0%                  ] 13 of 2000 complete in 19.2 sec
# [                  0%                  ] 14 of 2000 complete in 20.0 sec
# [                  0%                  ] 15 of 2000 complete in 20.6 sec
# [                  0%                  ] 14 of 2000 complete in 20.6 sec
# [                  0%                  ] 15 of 2000 complete in 21.3 sec
# [                  0%                  ] 15 of 2000 complete in 21.5 sec
# [                  0%                  ] 16 of 2000 complete in 22.1 sec
# [                  0%                  ] 15 of 2000 complete in 22.1 sec
# [                  0%                  ] 16 of 2000 complete in 23.0 sec
# [                  0%                  ] 16 of 2000 complete in 23.1 sec
# [                  0%                  ] 17 of 2000 complete in 23.7 sec
# [                  0%                  ] 16 of 2000 complete in 23.6 sec
# [                  0%                  ] 17 of 2000 complete in 24.5 sec
# [                  0%                  ] 17 of 2000 complete in 24.7 sec
# [                  0%                  ] 18 of 2000 complete in 25.1 sec
# [                  0%                  ] 17 of 2000 complete in 25.1 sec
# [                  0%                  ] 18 of 2000 complete in 26.3 sec
# [                  0%                  ] 18 of 2000 complete in 26.3 sec
# [                  0%                  ] 19 of 2000 complete in 26.6 sec
# [                  0%                  ] 18 of 2000 complete in 26.6 sec
# [                  0%                  ] 19 of 2000 complete in 27.9 sec
# [                  0%                  ] 19 of 2000 complete in 27.8 sec
# [                  1%                  ] 20 of 2000 complete in 28.1 sec
# [                  0%                  ] 19 of 2000 complete in 28.1 sec
# [                  1%                  ] 20 of 2000 complete in 29.4 sec
# [                  1%                  ] 20 of 2000 complete in 29.4 sec
# [                  1%                  ] 21 of 2000 complete in 29.5 sec
# [                  1%                  ] 20 of 2000 complete in 29.6 sec
# [                  1%                  ] 21 of 2000 complete in 31.0 sec
# [                  1%                  ] 21 of 2000 complete in 31.1 sec
# [                  1%                  ] 22 of 2000 complete in 31.0 sec
# [                  1%                  ] 21 of 2000 complete in 31.1 sec
# [                  1%                  ] 22 of 2000 complete in 32.7 sec
# [                  1%                  ] 23 of 2000 complete in 32.6 sec
# [                  1%                  ] 22 of 2000 complete in 32.6 sec
# [                  1%                  ] 22 of 2000 complete in 32.7 sec
# [                  1%                  ] 23 of 2000 complete in 34.2 sec
# [                  1%                  ] 24 of 2000 complete in 34.0 sec
# [                  1%                  ] 23 of 2000 complete in 34.2 sec
# [                  1%                  ] 23 of 2000 complete in 34.3 sec
# [                  1%                  ] 24 of 2000 complete in 35.8 sec
# [                  1%                  ] 25 of 2000 complete in 35.6 sec
# [                  1%                  ] 24 of 2000 complete in 35.8 sec
# [                  1%                  ] 24 of 2000 complete in 35.9 sec
# [                  1%                  ] 25 of 2000 complete in 37.4 sec
# [                  1%                  ] 26 of 2000 complete in 37.1 sec
# [                  1%                  ] 25 of 2000 complete in 37.3 sec
# [                  1%                  ] 25 of 2000 complete in 37.5 sec
# [                  1%                  ] 26 of 2000 complete in 39.0 sec
# [                  1%                  ] 27 of 2000 complete in 38.7 sec
# [                  1%                  ] 26 of 2000 complete in 38.9 sec
# [                  1%                  ] 26 of 2000 complete in 39.1 sec
# [                  1%                  ] 27 of 2000 complete in 40.5 sec
# [                  1%                  ] 28 of 2000 complete in 40.3 sec
# [                  1%                  ] 27 of 2000 complete in 40.5 sec
# [                  1%                  ] 27 of 2000 complete in 40.8 sec
# [                  1%                  ] 28 of 2000 complete in 42.0 sec
# [                  1%                  ] 29 of 2000 complete in 41.9 sec
# [                  1%                  ] 28 of 2000 complete in 42.0 sec
# [                  1%                  ] 28 of 2000 complete in 42.4 sec
# [                  1%                  ] 29 of 2000 complete in 43.6 sec
# [                  1%                  ] 30 of 2000 complete in 43.4 sec
# [                  1%                  ] 29 of 2000 complete in 43.5 sec
# [                  1%                  ] 29 of 2000 complete in 44.0 sec
# [                  1%                  ] 30 of 2000 complete in 45.1 sec
# [                  1%                  ] 31 of 2000 complete in 44.8 sec
# [                  1%                  ] 30 of 2000 complete in 45.1 sec
# [                  1%                  ] 30 of 2000 complete in 45.8 sec
# [                  1%                  ] 31 of 2000 complete in 46.7 sec
# [                  1%                  ] 32 of 2000 complete in 46.3 sec
# [                  1%                  ] 31 of 2000 complete in 46.7 sec
# [                  1%                  ] 31 of 2000 complete in 47.4 sec
# [                  1%                  ] 33 of 2000 complete in 47.8 sec
# [                  1%                  ] 32 of 2000 complete in 48.3 sec
# [                  1%                  ] 32 of 2000 complete in 48.3 sec
# [                  1%                  ] 34 of 2000 complete in 49.3 sec
# [                  1%                  ] 32 of 2000 complete in 49.1 sec
# [                  1%                  ] 33 of 2000 complete in 49.9 sec
# [                  1%                  ] 33 of 2000 complete in 49.8 sec
# [                  1%                  ] 35 of 2000 complete in 50.8 sec
# [                  1%                  ] 33 of 2000 complete in 50.7 sec
# [                  1%                  ] 34 of 2000 complete in 51.5 sec
# [                  1%                  ] 34 of 2000 complete in 51.4 sec
# [                  1%                  ] 36 of 2000 complete in 52.3 sec
# [                  1%                  ] 34 of 2000 complete in 52.2 sec
# [                  1%                  ] 35 of 2000 complete in 53.0 sec
# [                  1%                  ] 35 of 2000 complete in 52.9 sec
# [                  1%                  ] 37 of 2000 complete in 53.8 sec
# [                  1%                  ] 36 of 2000 complete in 54.5 sec
# [                  1%                  ] 35 of 2000 complete in 53.9 sec
# [                  1%                  ] 36 of 2000 complete in 54.6 sec
# [                  1%                  ] 38 of 2000 complete in 55.3 sec
# [                  1%                  ] 37 of 2000 complete in 56.0 sec
# [                  1%                  ] 36 of 2000 complete in 55.5 sec
# [                  1%                  ] 37 of 2000 complete in 56.2 sec
# [                  1%                  ] 39 of 2000 complete in 56.7 sec
# [                  1%                  ] 38 of 2000 complete in 57.5 sec
# [                  1%                  ] 37 of 2000 complete in 57.1 sec
# [                  1%                  ] 38 of 2000 complete in 57.8 sec
# [                  2%                  ] 40 of 2000 complete in 58.2 sec
# [                  1%                  ] 39 of 2000 complete in 59.0 sec
# [                  1%                  ] 38 of 2000 complete in 58.8 sec
# [                  1%                  ] 39 of 2000 complete in 59.4 sec
# [                  2%                  ] 41 of 2000 complete in 59.7 sec
# [                  2%                  ] 40 of 2000 complete in 60.5 sec
# [                  1%                  ] 39 of 2000 complete in 60.4 sec
# [                  2%                  ] 40 of 2000 complete in 60.9 sec
# [                  2%                  ] 42 of 2000 complete in 61.2 sec
# [                  2%                  ] 41 of 2000 complete in 62.1 sec
# [                  2%                  ] 40 of 2000 complete in 62.2 sec
# [                  2%                  ] 41 of 2000 complete in 62.6 sec
# [                  2%                  ] 43 of 2000 complete in 62.7 sec
# [                  2%                  ] 42 of 2000 complete in 63.7 sec
# [                  2%                  ] 41 of 2000 complete in 63.8 sec
# [                  2%                  ] 44 of 2000 complete in 64.1 sec
# [                  2%                  ] 42 of 2000 complete in 64.3 sec
# [                  2%                  ] 43 of 2000 complete in 65.2 sec
# [                  2%                  ] 45 of 2000 complete in 65.6 sec
# [                  2%                  ] 42 of 2000 complete in 65.4 sec
# [                  2%                  ] 43 of 2000 complete in 65.9 sec
# [                  2%                  ] 44 of 2000 complete in 66.8 sec
# [                  2%                  ] 46 of 2000 complete in 67.1 sec
# [                  2%                  ] 43 of 2000 complete in 67.1 sec
# [                  2%                  ] 44 of 2000 complete in 67.6 sec
# [                  2%                  ] 45 of 2000 complete in 68.4 sec
# [                  2%                  ] 47 of 2000 complete in 68.5 sec
# [                  2%                  ] 44 of 2000 complete in 68.8 sec
# [                  2%                  ] 45 of 2000 complete in 69.4 sec
# [                  2%                  ] 46 of 2000 complete in 69.9 sec
# [                  2%                  ] 48 of 2000 complete in 70.0 sec
# [                  2%                  ] 45 of 2000 complete in 70.5 sec
# [                  2%                  ] 47 of 2000 complete in 71.7 sec
# [                  2%                  ] 46 of 2000 complete in 71.3 sec
# [                  2%                  ] 49 of 2000 complete in 72.0 sec
# [                  2%                  ] 46 of 2000 complete in 72.6 sec
# [                  2%                  ] 48 of 2000 complete in 73.6 sec
# [                  2%                  ] 47 of 2000 complete in 73.3 sec
# [                  2%                  ] 50 of 2000 complete in 73.7 sec
# [                  2%                  ] 47 of 2000 complete in 74.3 sec
# [                  2%                  ] 49 of 2000 complete in 75.2 sec
# [                  2%                  ] 48 of 2000 complete in 75.0 sec
# [                  2%                  ] 51 of 2000 complete in 75.1 sec
# [                  2%                  ] 48 of 2000 complete in 75.9 sec
# [                  2%                  ] 50 of 2000 complete in 76.8 sec
# [                  2%                  ] 52 of 2000 complete in 76.5 sec
# [                  2%                  ] 49 of 2000 complete in 76.7 sec
# [                  2%                  ] 49 of 2000 complete in 77.4 sec
# [                  2%                  ] 51 of 2000 complete in 78.2 sec
# [-                 2%                  ] 53 of 2000 complete in 78.1 sec
# [                  2%                  ] 50 of 2000 complete in 78.4 sec
# [                  2%                  ] 50 of 2000 complete in 79.0 sec
# [                  2%                  ] 52 of 2000 complete in 79.9 sec
# [-                 2%                  ] 54 of 2000 complete in 79.6 sec
# [                  2%                  ] 51 of 2000 complete in 80.0 sec
# [                  2%                  ] 51 of 2000 complete in 80.7 sec
# ...
# [-----------------97%----------------- ] 1951 of 2000 complete in 2932.9 sec
# [-----------------95%----------------  ] 1917 of 2000 complete in 2933.1 sec
# [-----------------96%----------------  ] 1936 of 2000 complete in 2933.4 sec
# [-----------------97%----------------- ] 1952 of 2000 complete in 2934.3 sec
# [-----------------95%----------------  ] 1918 of 2000 complete in 2934.7 sec
# [-----------------97%----------------- ] 1953 of 2000 complete in 2935.5 sec
# [-----------------96%----------------  ] 1937 of 2000 complete in 2934.9 sec
# [-----------------95%----------------  ] 1919 of 2000 complete in 2936.1 sec
# [-----------------97%----------------- ] 1954 of 2000 complete in 2936.7 sec
# [-----------------96%----------------  ] 1938 of 2000 complete in 2936.4 sec
# [-----------------96%----------------  ] 1920 of 2000 complete in 2937.6 sec
# [-----------------97%----------------- ] 1955 of 2000 complete in 2938.0 sec
# [-----------------96%----------------  ] 1939 of 2000 complete in 2937.9 sec
# [-----------------97%----------------- ] 1956 of 2000 complete in 2939.2 sec
# [-----------------96%----------------  ] 1921 of 2000 complete in 2938.9 sec
# [-----------------97%----------------  ] 1940 of 2000 complete in 2939.4 sec
# [-----------------97%----------------- ] 1957 of 2000 complete in 2940.4 sec
# [-----------------96%----------------  ] 1922 of 2000 complete in 2940.4 sec
# [-----------------97%----------------  ] 1941 of 2000 complete in 2940.9 sec
# [-----------------97%----------------- ] 1958 of 2000 complete in 2941.7 sec
# [-----------------96%----------------  ] 1923 of 2000 complete in 2941.9 sec
# [-----------------97%----------------- ] 1959 of 2000 complete in 2942.9 sec
# [-----------------97%----------------  ] 1942 of 2000 complete in 2942.4 sec
# [-----------------96%----------------  ] 1924 of 2000 complete in 2943.3 sec
# [-----------------98%----------------- ] 1960 of 2000 complete in 2944.1 sec
# [-----------------97%----------------  ] 1943 of 2000 complete in 2944.0 sec
# [-----------------96%----------------  ] 1925 of 2000 complete in 2944.7 sec
# [-----------------98%----------------- ] 1961 of 2000 complete in 2945.3 sec
# [-----------------97%----------------  ] 1944 of 2000 complete in 2945.5 sec
# [-----------------98%----------------- ] 1962 of 2000 complete in 2946.5 sec
# [-----------------96%----------------  ] 1926 of 2000 complete in 2946.2 sec
# [-----------------98%----------------- ] 1963 of 2000 complete in 2947.6 sec
# [-----------------97%----------------  ] 1945 of 2000 complete in 2947.1 sec
# [-----------------96%----------------  ] 1927 of 2000 complete in 2947.6 sec
# [-----------------98%----------------- ] 1964 of 2000 complete in 2948.8 sec
# [-----------------97%----------------  ] 1946 of 2000 complete in 2948.6 sec
# [-----------------96%----------------  ] 1928 of 2000 complete in 2949.1 sec
# [-----------------98%----------------- ] 1965 of 2000 complete in 2950.1 sec
# [-----------------97%----------------  ] 1947 of 2000 complete in 2950.1 sec
# [-----------------96%----------------  ] 1929 of 2000 complete in 2950.5 sec
# [-----------------98%----------------- ] 1966 of 2000 complete in 2951.3 sec
# [-----------------97%----------------- ] 1948 of 2000 complete in 2951.7 sec
# [-----------------96%----------------  ] 1930 of 2000 complete in 2951.9 sec
# [-----------------98%----------------- ] 1967 of 2000 complete in 2952.5 sec
# [-----------------97%----------------- ] 1949 of 2000 complete in 2953.0 sec
# [-----------------96%----------------  ] 1931 of 2000 complete in 2953.4 sec
# [-----------------98%----------------- ] 1968 of 2000 complete in 2953.8 sec
# [-----------------98%----------------- ] 1969 of 2000 complete in 2955.0 sec
# [-----------------96%----------------  ] 1932 of 2000 complete in 2954.8 sec
# [-----------------97%----------------- ] 1950 of 2000 complete in 2954.6 sec
# [-----------------98%----------------- ] 1970 of 2000 complete in 2956.3 sec
# [-----------------96%----------------  ] 1933 of 2000 complete in 2956.3 sec
# [-----------------97%----------------- ] 1951 of 2000 complete in 2956.1 sec
# [-----------------98%----------------- ] 1971 of 2000 complete in 2957.6 sec
# [-----------------96%----------------  ] 1934 of 2000 complete in 2957.7 sec
# [-----------------97%----------------- ] 1952 of 2000 complete in 2957.6 sec
# [-----------------98%----------------- ] 1972 of 2000 complete in 2958.8 sec
# [-----------------96%----------------  ] 1935 of 2000 complete in 2959.1 sec
# [-----------------97%----------------- ] 1953 of 2000 complete in 2959.0 sec
# [-----------------98%----------------- ] 1973 of 2000 complete in 2960.3 sec
# [-----------------96%----------------  ] 1936 of 2000 complete in 2960.5 sec
# [-----------------97%----------------- ] 1954 of 2000 complete in 2960.5 sec
# [-----------------98%----------------- ] 1974 of 2000 complete in 2961.5 sec
# [-----------------96%----------------  ] 1937 of 2000 complete in 2962.0 sec
# [-----------------97%----------------- ] 1955 of 2000 complete in 2961.9 sec
# [-----------------98%----------------- ] 1975 of 2000 complete in 2962.7 sec
# [-----------------96%----------------  ] 1938 of 2000 complete in 2963.4 sec
# [-----------------97%----------------- ] 1956 of 2000 complete in 2963.3 sec
# [-----------------98%----------------- ] 1976 of 2000 complete in 2964.0 sec
# [-----------------96%----------------  ] 1939 of 2000 complete in 2964.9 sec
# [-----------------98%----------------- ] 1977 of 2000 complete in 2965.3 sec
# [-----------------97%----------------- ] 1957 of 2000 complete in 2964.8 sec
# [-----------------98%----------------- ] 1978 of 2000 complete in 2966.7 sec
# [-----------------97%----------------  ] 1940 of 2000 complete in 2966.4 sec
# [-----------------97%----------------- ] 1958 of 2000 complete in 2966.3 sec
# [-----------------98%----------------- ] 1979 of 2000 complete in 2968.0 sec
# [-----------------97%----------------  ] 1941 of 2000 complete in 2968.0 sec
# [-----------------97%----------------- ] 1959 of 2000 complete in 2967.8 sec
# [-----------------99%----------------- ] 1980 of 2000 complete in 2969.3 sec
# [-----------------97%----------------  ] 1942 of 2000 complete in 2969.4 sec
# [-----------------98%----------------- ] 1960 of 2000 complete in 2969.3 sec
# [-----------------99%----------------- ] 1981 of 2000 complete in 2970.6 sec
# [-----------------97%----------------  ] 1943 of 2000 complete in 2970.9 sec
# [-----------------98%----------------- ] 1961 of 2000 complete in 2970.9 sec
# [-----------------99%----------------- ] 1982 of 2000 complete in 2972.0 sec
# [-----------------97%----------------  ] 1944 of 2000 complete in 2972.7 sec
# [-----------------98%----------------- ] 1962 of 2000 complete in 2972.9 sec
# [-----------------99%----------------- ] 1983 of 2000 complete in 2973.9 sec
# [-----------------97%----------------  ] 1945 of 2000 complete in 2974.6 sec
# [-----------------98%----------------- ] 1963 of 2000 complete in 2974.6 sec
# [-----------------99%----------------- ] 1984 of 2000 complete in 2975.5 sec
# [-----------------97%----------------  ] 1946 of 2000 complete in 2976.7 sec
# [-----------------98%----------------- ] 1964 of 2000 complete in 2976.7 sec
# [-----------------99%----------------- ] 1985 of 2000 complete in 2977.4 sec
# [-----------------97%----------------  ] 1947 of 2000 complete in 2978.7 sec
# [-----------------99%----------------- ] 1986 of 2000 complete in 2979.1 sec
# [-----------------98%----------------- ] 1965 of 2000 complete in 2978.6 sec
# [-----------------99%----------------- ] 1987 of 2000 complete in 2980.5 sec
# [-----------------97%----------------- ] 1948 of 2000 complete in 2980.2 sec
# [-----------------98%----------------- ] 1966 of 2000 complete in 2980.1 sec
# [-----------------99%----------------- ] 1988 of 2000 complete in 2981.8 sec
# [-----------------97%----------------- ] 1949 of 2000 complete in 2981.7 sec
# [-----------------98%----------------- ] 1967 of 2000 complete in 2981.7 sec
# [-----------------99%----------------- ] 1989 of 2000 complete in 2983.2 sec
# [-----------------97%----------------- ] 1950 of 2000 complete in 2983.3 sec
# [-----------------98%----------------- ] 1968 of 2000 complete in 2983.4 sec
# [-----------------99%----------------- ] 1990 of 2000 complete in 2984.5 sec
# [-----------------97%----------------- ] 1951 of 2000 complete in 2984.7 sec
# [-----------------98%----------------- ] 1969 of 2000 complete in 2984.9 sec
# [-----------------99%----------------- ] 1991 of 2000 complete in 2985.9 sec
# [-----------------97%----------------- ] 1952 of 2000 complete in 2986.1 sec
# [-----------------98%----------------- ] 1970 of 2000 complete in 2986.5 sec
# [-----------------99%----------------- ] 1992 of 2000 complete in 2987.2 sec
# [-----------------97%----------------- ] 1953 of 2000 complete in 2987.6 sec
# [-----------------99%----------------- ] 1993 of 2000 complete in 2988.4 sec
# [-----------------98%----------------- ] 1971 of 2000 complete in 2988.1 sec
# [-----------------97%----------------- ] 1954 of 2000 complete in 2989.0 sec
# [-----------------99%----------------- ] 1994 of 2000 complete in 2989.8 sec
# [-----------------98%----------------- ] 1972 of 2000 complete in 2989.6 sec
# [-----------------97%----------------- ] 1955 of 2000 complete in 2990.5 sec
# [-----------------99%----------------- ] 1995 of 2000 complete in 2991.2 sec
# [-----------------98%----------------- ] 1973 of 2000 complete in 2991.1 sec
# [-----------------97%----------------- ] 1956 of 2000 complete in 2992.0 sec
# [-----------------99%----------------- ] 1996 of 2000 complete in 2992.6 sec
# [-----------------98%----------------- ] 1974 of 2000 complete in 2992.6 sec
# [-----------------97%----------------- ] 1957 of 2000 complete in 2993.5 sec
# [-----------------99%----------------- ] 1997 of 2000 complete in 2993.9 sec
# [-----------------98%----------------- ] 1975 of 2000 complete in 2994.0 sec
# [-----------------99%----------------- ] 1998 of 2000 complete in 2995.3 sec
# [-----------------97%----------------- ] 1958 of 2000 complete in 2995.0 sec
# [-----------------98%----------------- ] 1976 of 2000 complete in 2995.5 sec
# [-----------------99%----------------- ] 1999 of 2000 complete in 2996.6 sec
# [-----------------97%----------------- ] 1959 of 2000 complete in 2996.5 sec
# [-----------------98%----------------- ] 1977 of 2000 complete in 2997.0 sec
# [-----------------100%-----------------] 2000 of 2000 complete in 2997.9 sec
# [-----------------98%----------------- ] 1960 of 2000 complete in 2998.1 sec
# [-----------------98%----------------- ] 1978 of 2000 complete in 2998.4 sec
# [-----------------100%-----------------] 2001 of 2000 complete in 2999.3 sec
# [-----------------98%----------------- ] 1961 of 2000 complete in 2999.8 sec
# [-----------------98%----------------- ] 1979 of 2000 complete in 3000.1 sec
# [-----------------98%----------------- ] 1962 of 2000 complete in 3001.4 sec
# [-----------------99%----------------- ] 1980 of 2000 complete in 3001.7 sec
# [-----------------98%----------------- ] 1963 of 2000 complete in 3003.1 sec
# [-----------------99%----------------- ] 1981 of 2000 complete in 3003.5 sec
# [-----------------98%----------------- ] 1964 of 2000 complete in 3004.9 sec
# [-----------------99%----------------- ] 1982 of 2000 complete in 3005.1 sec
# [-----------------98%----------------- ] 1965 of 2000 complete in 3006.6 sec
# [-----------------99%----------------- ] 1983 of 2000 complete in 3006.8 sec
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.
# [-----------------98%----------------- ] 1966 of 2000 complete in 3008.3 sec
# [-----------------99%----------------- ] 1984 of 2000 complete in 3008.4 sec
# [-----------------98%----------------- ] 1967 of 2000 complete in 3010.0 sec
# [-----------------99%----------------- ] 1985 of 2000 complete in 3010.0 sec
# [-----------------98%----------------- ] 1968 of 2000 complete in 3011.8 sec
# [-----------------99%----------------- ] 1986 of 2000 complete in 3011.6 sec
# [-----------------99%----------------- ] 1987 of 2000 complete in 3013.1 sec
# [-----------------98%----------------- ] 1969 of 2000 complete in 3013.6 sec
# [-----------------99%----------------- ] 1988 of 2000 complete in 3014.9 sec
# [-----------------98%----------------- ] 1970 of 2000 complete in 3015.2 sec
# [-----------------99%----------------- ] 1989 of 2000 complete in 3016.6 sec
# [-----------------98%----------------- ] 1971 of 2000 complete in 3016.8 sec
# [-----------------99%----------------- ] 1990 of 2000 complete in 3018.1 sec
# [-----------------98%----------------- ] 1972 of 2000 complete in 3018.5 sec
# [-----------------99%----------------- ] 1991 of 2000 complete in 3019.6 sec
# [-----------------98%----------------- ] 1973 of 2000 complete in 3020.0 sec
# [-----------------99%----------------- ] 1992 of 2000 complete in 3021.0 sec
# [-----------------98%----------------- ] 1974 of 2000 complete in 3021.5 sec
# [-----------------99%----------------- ] 1993 of 2000 complete in 3022.5 sec
# [-----------------98%----------------- ] 1975 of 2000 complete in 3023.1 sec
# [-----------------99%----------------- ] 1994 of 2000 complete in 3023.9 sec
# [-----------------98%----------------- ] 1976 of 2000 complete in 3024.5 sec
# [-----------------99%----------------- ] 1995 of 2000 complete in 3025.5 sec
# [-----------------98%----------------- ] 1977 of 2000 complete in 3025.9 sec
# [-----------------98%----------------- ] 1978 of 2000 complete in 3027.3 sec
# [-----------------99%----------------- ] 1996 of 2000 complete in 3027.1 sec
# [-----------------98%----------------- ] 1979 of 2000 complete in 3028.8 sec
# [-----------------99%----------------- ] 1997 of 2000 complete in 3028.7 sec
# [-----------------99%----------------- ] 1980 of 2000 complete in 3030.3 sec
# [-----------------99%----------------- ] 1998 of 2000 complete in 3030.2 sec
# [-----------------99%----------------- ] 1981 of 2000 complete in 3031.8 sec
# [-----------------99%----------------- ] 1999 of 2000 complete in 3031.7 sec
# [-----------------99%----------------- ] 1982 of 2000 complete in 3033.3 sec
# [-----------------100%-----------------] 2000 of 2000 complete in 3033.3 sec
# [-----------------99%----------------- ] 1983 of 2000 complete in 3034.9 sec
# [-----------------100%-----------------] 2001 of 2000 complete in 3034.9 sec
# [-----------------99%----------------- ] 1984 of 2000 complete in 3036.7 sec
# [-----------------99%----------------- ] 1985 of 2000 complete in 3038.3 sec
# [-----------------99%----------------- ] 1986 of 2000 complete in 3040.1 sec
# [-----------------99%----------------- ] 1987 of 2000 complete in 3041.8 sec
# [-----------------99%----------------- ] 1988 of 2000 complete in 3043.5 sec
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.
# [-----------------99%----------------- ] 1989 of 2000 complete in 3045.1 sec
# [-----------------99%----------------- ] 1990 of 2000 complete in 3046.7 sec
# [-----------------99%----------------- ] 1991 of 2000 complete in 3048.4 sec
# [-----------------99%----------------- ] 1992 of 2000 complete in 3050.1 sec
# [-----------------99%----------------- ] 1993 of 2000 complete in 3051.7 sec
# [-----------------99%----------------- ] 1994 of 2000 complete in 3053.5 sec
# [-----------------99%----------------- ] 1995 of 2000 complete in 3055.2 sec
# [-----------------99%----------------- ] 1996 of 2000 complete in 3056.7 sec
# [-----------------99%----------------- ] 1997 of 2000 complete in 3058.2 sec
# [-----------------99%----------------- ] 1998 of 2000 complete in 3059.7 sec
# [-----------------99%----------------- ] 1999 of 2000 complete in 3061.1 sec
# [-----------------100%-----------------] 2000 of 2000 complete in 3062.6 sec
# [-----------------100%-----------------] 2001 of 2000 complete in 3064.1 sec
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.

# %% [markdown]
# ### convert hddm model object to Inferencedata

# %%
file_names = glob.glob('infdata_ms2_netcdf',recursive=False)
if file_names:
    infdata_ms2 = az.from_netcdf('infdata_ms2_netcdf')
else:
    InfData_ms2 = InferenceDataFromHDDM(ms2res, nppc = 300, save_name="infdata_ms2")

# %% [markdown]
# ## visualization

# %%
m2 = kabuki.utils.concat_models(ms2res)
m2.plot_posteriors()

# %%
az.plot_trace(InfData_ms2, 
              var_names=("^v(?!.*(subj|std))"), 
              filter_vars='regex')

# %%
az.plot_trace(InfData_ms2, 
              var_names=("^z(?!.*(subj|std))"), 
              filter_vars='regex')

# %% [markdown]
# ### summary data

# %%
ms2_summary_tmp = az.summary(InfData_ms2, round_to=4)
ms2_summary_tmp.sort_values('r_hat')

# %% [markdown]
# ### posterior predictive check

# %%
az.plot_ppc(InfData_ms2,
            var_names=['rt','response'], 
            textsize=20, 
            num_pp_samples=300, 
            alpha = 0.2)

# %% [markdown]
# ### Check dic, loo and waic

# %%
# dic
m2.dic
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.
# -1589.737085887929

# %%
# loo
az.loo(InfData_ms2, scale="deviance")

# %%
# waic
az.waic(InfData_ms2, scale="deviance")

# %% [markdown]
# ### posterior predictive check by condition

# %%
# coherence
plot_ppc_by_cond(data = InfData_ms2, 
                 or_d = df, 
                 subjs = [3], 
                 conds = ['coherence'], 
                 num_pp_samples=300, 
                 random_seed = 7, 
                 alpha = 0.2, 
                 grid = [2,2], 
                 textsize=20, 
                 var_names=['rt'])

# %%
# attention
plot_ppc_by_cond(data = InfData_ms2, 
                 or_d = df, 
                 subjs = [3], 
                 conds = ['attention'], 
                 num_pp_samples=300, 
                 random_seed = 7, 
                 alpha = 0.2, 
                 grid = [2,2], 
                 textsize=20, 
                 var_names=['rt'])

# %% [markdown]
# ## Statistical Inference

# %%
az.plot_posterior(InfData['ms2'], 
                  filter_vars='regex', 
                  var_names=("^v_(?!.*(subj|std|Intercept))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=v_int)

# %%
az.plot_posterior(InfData['ms2'], 
                  filter_vars='regex', 
                  var_names=("^v_(?!.*(subj|std|coherence))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=v_coh)

# %%
# z_int
az.plot_posterior(InfData['ms2'], 
                  filter_vars='regex', 
                  var_names=("^z_(?!.*(subj|std|Intercept))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=t_int)

# %%
# z_coh
az.plot_posterior(InfData['ms2'], 
                  filter_vars='regex', 
                  var_names=("^z_(?!.*(subj|std|attention))"), 
                  kind='hist', 
                  hdi_prob=0.95,
                  ref_val=t_pri)
